# %% [markdown]
# # **Make Pretrained-Model FaceNet !**

# %% [markdown]
# ## 0.미션

# %% [markdown]
# ### (1) 미션1
# 여러분은 노트북에서 얼굴 인식 파일을 실행시키기 위해 사전 학습 모델을 만들어야 합니다.
#
# 그 전에 가지고 있는 데이터셋을 **학습에 적합한 형태**로 만들어야 합니다.
#
# - 1) 데이터셋을 불러옵니다.
#     - 데이터셋은 2가지입니다. 본인의 얼굴 이미지 파일, 다른 사람의 얼굴 이미지 파일.
# - 2) 데이터셋을 전처리합니다.
#     - Keras에는 **실제로 존재하는 이미지 데이터를 처리**해주는 함수가 있습니다.

# %% [markdown]
# ### (2) 미션2
# 데이터셋을 **학습에 적합한 형태**로 만들었다면, **FaceNet 모델로 Transfer Learning**을 수행합니다.
#
# - 1) FaceNet 모델 구조를 생성합니다.
#     - [FaceNet 논문 링크](https://arxiv.org/abs/1503.03832)
#     - FaceNet의 Input은 (160, 160) 사이즈의 이미지입니다.
# - 2) FaceNet 모델 구조 + 구조 추가
#     - FaceNet의 Output은 128차원의 벡터입니다.
#     - 이 과정을 Transfer Learning라고 합니다.

# %% [markdown]
# ### (3) 미션3
# 학습된 모델로 추론하여 성능 지표를 확인하고 모델을 개선시키세요.
#
# 그 후, 모델의 구조와 가중치를 **반드시 저장**하여 여러분의 노트북에 옮기세요.
#
# - 1) 다양한 모델을 사용해보세요.
#     - 모델에 정해진 정답은 없습니다.
#     - 성능 지표에서 무엇이 중요한지 깊게 생각하세요.
#     - 사전 학습된 FaceNet 모델을 사용하셔도 좋고, 아예 독창적으로 여러분만의 모델을 만드셔도 좋습니다!
# - 2) 모델을 **반드시 저장**하세요.
#     - .keras 형태로 우선 Colab에 저장하세요.
#     - Colab에 생성된 .keras 파일을 **로컬에 다운로드** 합니다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project4 폴더를 만드세요.
#         * 데이터 파일을 복사해 넣습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/project4'

# %% [markdown]
# ### (2) 라이브러리 설치 및 불러오기

# %% [markdown]
# * 라이브러리 로딩

# %%
## colab에서 세션 재시작을 요구하는 팝업이 뜨면 재시작 누르세요.
# !pip install keras-nightly
# Out:
# Collecting keras-nightly
#   Downloading keras_nightly-3.7.0.dev2024110103-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras-nightly) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nightly) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nightly) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-nightly) (0.1.2)
# Downloading keras_nightly-3.7.0.dev2024110103-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 49.9 MB/s eta 0:00:00
# Installing collected packages: keras-nightly
# Successfully installed keras-nightly-3.7.0.dev2024110103

# %% [markdown]
# ## 3.미션1

# %% [markdown]
# 여러분은 노트북에서 얼굴 인식 파일을 실행시키기 위해 사전 학습 모델을 만들어야 합니다.
#
# 그 전에 가지고 있는 데이터셋을 **학습에 적합한 형태**로 만들어야 합니다.
#
# - 1) 데이터셋을 불러옵니다.
#     - 데이터셋은 2가지입니다. 본인의 얼굴 이미지 파일, 다른 사람의 얼굴 이미지 파일.
# - 2) 데이터셋을 전처리합니다.
#     - Keras에는 **실제로 존재하는 이미지 데이터를 처리**해주는 함수가 있습니다.

# %% [markdown]
# ### (1) 데이터셋 불러오기

# %% [markdown]
# * **세부 요구사항**
#     - 데이터셋을 불러옵니다.
#         - 데이터셋은 두 개의 압축 파일이어야 합니다.
#             1. lfw-deepfunneled.zip : Labeled Faces in the Wild 데이터셋
#             2. 여러분의 얼굴 이미지 데이터셋
#                 - 여러분의 얼굴 이미지가 담긴 **압축 파일**을 **Google Drive에 업로드** 하기를 권장합니다.
#                     - 이미지 파일 하나하나 업로드 하면 시간이 오래 걸립니다.
#     - 데이터셋 압축 파일을 **Colab에 폴더를 생성한 후 해제**하세요.
#         - 데이터셋 폴더를 **본인 얼굴 폴더, LFW 폴더로 나누어** 생성하는 것을 권장합니다.
#         - 만일 두 압축 파일을 하나의 폴더에 모두 해제하면 전처리가 더 까다로워질 것입니다.
#     - 예시 코드에서 사용한 라이브러리
#         - os, zipfile

# %% [markdown]
# #### 1) 본인 얼굴 이미지 데이터셋 불러오기

# %%
import os
import zipfile

# %%
data_myFace = os.path.join('/content/drive/MyDrive/project4/my_face_exam.zip')
data_myFace
# Out:
# '/content/drive/MyDrive/project4/my_face_exam.zip'

# %%
## Colab에 생성할 본인 얼굴 폴더 경로
extract_folder = '/content/my_face'

## 위의 경로에 폴더가 없을 때 생성
if not os.path.exists(extract_folder) :
    os.makedirs(extract_folder)

## 위의 경로에 압축을 해제
with zipfile.ZipFile(data_myFace, 'r') as zip_ref :
    file_list = zip_ref.namelist()

    for f in file_list :
        if not f.endswith('/') and f.lower().endswith('.jpg') :
            file_name = os.path.basename(f)

            if not file_name.startswith('._') :
                d_path = os.path.join(extract_folder, file_name)

                with zip_ref.open(f) as source, open(d_path, 'wb') as target :
                    target.write(source.read())

# %%
## 생성된 본인 얼굴 이미지 데이터 폴더 안의 이미지 수
len(os.listdir(extract_folder) )
# Out:
# 11088

# %% [markdown]
# #### 2) 다른 얼굴 이미지 데이터셋 불러오기

# %%
data_other = '/content/drive/MyDrive/project4/Datasets/Keras/lfw-deepfunneled.zip'
data_other
# Out:
# '/content/drive/MyDrive/project4/Datasets/Keras/lfw-deepfunneled.zip'

# %%
## Colab에 생성할 다른 얼굴 폴더 경로
extract_folder = '/content/other_face'

## 위의 경로에 폴더가 없을 때 생성
if not os.path.exists(extract_folder) :
    os.makedirs(extract_folder)

## 위의 경로에 압축을 해제
with zipfile.ZipFile(data_other, 'r') as zip_ref :
    file_list = zip_ref.namelist()

    for f in file_list :
        if not f.endswith('/') and f.lower().endswith('.jpg') :
            file_name = os.path.basename(f)

            if not file_name.startswith('._') :
                d_path = os.path.join(extract_folder, file_name)

                with zip_ref.open(f) as source, open(d_path, 'wb') as target :
                    target.write(source.read())

# %%
## 생성된 다른 사람 얼굴 이미지 데이터 폴더 안의 이미지 수
len(os.listdir(extract_folder) )
# Out:
# 13233

# %% [markdown]
# ### (2) 데이터셋 전처리
# * **세부 요구사항**
#     - 데이터셋을 전처리 합니다.
#         - Training set, Validation set, Test set으로 데이터셋을 나누어 주세요.
#             - 학습 과정에서 Training set, Validation set을 사용해야 합니다.
#             - 추론 과정에서 Test set을 사용해야 합니다.
#         - Keras의 **특정 함수**가 실제 존재하는 이미지 파일에 대한 전처리를 쉽게 도와줍니다.
#         - **특정 함수**에서 요구하는 폴더 구조가 있습니다. **특정 함수**를 사용한다면 이에 맞춰서 폴더를 생성해야 합니다.
#         - 각 데이터셋에 스케일링도 적용하세요.
#     - 예시 코드에서 사용한 라이브러리
#         - glob, random, shutil, numpy, keras

# %% [markdown]
# #### 1) 데이터셋 분할

# %%
import glob
import random
import shutil
import numpy as np

from keras.utils import load_img, img_to_array
from keras.utils import image_dataset_from_directory

# %%
## image_dataset_from_directory를 사용하기 위해 Colab에 폴더 생성

## 생성될 폴더의 경로
tr_data = '/content/tr_data'
te_data = '/content/te_data'

## 폴더가 존재하지 않을 때 폴더를 생성
if not os.path.exists(tr_data) :
    os.makedirs(tr_data)

if not os.path.exists(te_data) :
    os.makedirs(te_data)

## 폴더 생성 확인
print(os.path.exists(tr_data) )
print(os.path.exists(te_data) )
# Out:
# True
# True

# %%
## Keras의 image_dataset_from_directory를 사용하기 위해 Colab에 하위 폴더 생성

## 생성될 폴더에 대한 하위 폴더 생성
class_names = ['my', 'other']

for cn in class_names :
    temp = os.path.join(tr_data, cn)

    if not os.path.exists( temp ) :
        os.makedirs(temp)

    ## 폴더 생성 확인
    print(os.path.exists(temp))

for cn in class_names :
    temp = os.path.join(te_data, cn)

    if not os.path.exists( temp ) :
        os.makedirs(temp)

    ## 폴더 생성 확인
    print(os.path.exists(temp))
# Out:
# True
# True
# True
# True

# %%
## 본인 얼굴 데이터가 있는 폴더 경로의 파일 전체를 정렬하여 리스트화
img_list_my = sorted(glob.glob('/content/my_face/*',))

## 다른 얼굴 데이터가 있는 폴더 경로의 파일 전체를 정렬하여 리스트화
img_list_other = sorted(glob.glob('/content/other_face/*'))

## 이미지 갯수 확인
len(img_list_my), len(img_list_other)
# Out:
# (11088, 13233)

# %%
## 얼굴 데이터를 Training set, Test set으로 분할하기 위한 사전 작업
## 분할 재현성을 위한 난수 고정
random.seed(2024)
random.shuffle(img_list_my)
random.shuffle(img_list_other)

img_list_my[:5], img_list_other[:5]
# Out:
# (['/content/my_face/my_face_370 - ║╣╗τ║╗ (4) - ║╣╗τ║╗ - ║╣╗τ║╗.jpg',
#   '/content/my_face/my_face_25 - ║╣╗τ║╗ - ║╣╗τ║╗ (2).jpg',
#   '/content/my_face/my_face_133 - ║╣╗τ║╗ (4).jpg',
#   '/content/my_face/my_face_435 - ║╣╗τ║╗ - ║╣╗τ║╗ - ║╣╗τ║╗.jpg',
#   '/content/my_face/my_face_202 - ║╣╗τ║╗ - ║╣╗τ║╗.jpg'],
#  ['/content/other_face/Emmit_Smith_0002.jpg',
#   '/content/other_face/Kyle_McLaren_0001.jpg',
#   '/content/other_face/Mike_Price_0001.jpg',
#   '/content/other_face/Marcus_Gronholm_0001.jpg',
#   '/content/other_face/Enrique_Bolanos_0005.jpg'])

# %%
## Test set의 비율 설정
test_size = 0.2

## 나의 얼굴 파일 리스트와 다른 얼굴 파일 리스트에 대한 반복문
for i_l in [img_list_my, img_list_other] :
    ## 리스트의 길이 체크
    # list_len = len(i_l)
    list_len = 11000  ## 예시 파일의 이미지 갯수가 맞지 않아서 11000개까지만 사용
    ## 데이터 분할을 위한 인덱스 설정
    split_idx = int(list_len * (1 - test_size) )

    ## 인덱스를 이용해 상위 리스트를 Training set, Test set 2가지로 세분화
    list_tr = i_l[ : split_idx]
    list_te = i_l[split_idx : list_len]

    ## 현재 리스트가 나의 얼굴 파일 리스트와 같다면
    if i_l == img_list_my :
        ## "나의 얼굴 파일 리스트"의 파일을 Training set 폴더 안의 "나의 얼굴 폴더"로 복사
        ## 이동이 잘못 되었을 경우를 생각하여 복사로 진행
        for file_path in list_tr :
            f_name = file_path.split('/')
            shutil.copy(src=file_path,
                        dst=tr_data+'/my/'+f_name[-1]
                        )
            print(f'파일 이동 완료 : {f_name[-1]}')

        ## "나의 얼굴 파일 리스트"의 파일을 Test set 폴더 안의 "나의 얼굴 폴더"로 복사
        ## 이동이 잘못 되었을 경우를 생각하여 복사로 진행
        for file_path in list_te :
            f_name = file_path.split('/')
            shutil.copy(src=file_path,
                        dst=te_data+'/my/'+f_name[-1]
                        )
            print(f'파일 이동 완료 : {f_name[-1]}')

    ## 현재 리스트가 "나의 얼굴 파일 리스트"가 아니라면 (즉, "다른 사람 얼굴 파일 리스트"라면)
    else :
        ## "다른 사람 얼굴 파일 리스트"의 파일을 Training set 폴더 안의 "다른 사람 얼굴 폴더"로 복사
        ## 이동이 잘못 되었을 경우를 생각하여 복사로 진행
        for file_path in list_tr :
            f_name = file_path.split('/')
            shutil.copy(src=file_path,
                        dst=tr_data+'/other/'+f_name[-1],
                        )
            print(f'파일 이동 완료 : {f_name[-1]}')

        ## "다른 사람 얼굴 파일 리스트"의 파일을 Test set 폴더 안의 "다른 사람 얼굴 폴더"로 복사
        ## 이동이 잘못 되었을 경우를 생각하여 복사로 진행
        for file_path in list_te :
            f_name = file_path.split('/')
            shutil.copy(src=file_path,
                        dst=te_data+'/other/'+f_name[-1]
                        )
            print(f'파일 이동 완료 : {f_name[-1]}')
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 파일 이동 완료 : Dick_Cheney_0009.jpg
# 파일 이동 완료 : Randy_Travis_0001.jpg
# 파일 이동 완료 : Colin_Powell_0104.jpg
# 파일 이동 완료 : Gordon_Brown_0003.jpg
# 파일 이동 완료 : Fred_Huff_0001.jpg
# 파일 이동 완료 : Dan_Morales_0003.jpg
# 파일 이동 완료 : Melissa_Etheridge_0001.jpg
# 파일 이동 완료 : Jiang_Zemin_0019.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0109.jpg
# 파일 이동 완료 : Queen_Elizabeth_II_0012.jpg
# 파일 이동 완료 : Nadia_Petrova_0003.jpg
# 파일 이동 완료 : Saddam_Hussein_0008.jpg
# 파일 이동 완료 : Colin_Powell_0141.jpg
# 파일 이동 완료 : Billy_Beane_0001.jpg
# 파일 이동 완료 : Elijah_Wood_0003.jpg
# 파일 이동 완료 : George_W_Bush_0333.jpg
# 파일 이동 완료 : Gonzalo_Sanchez_de_Lozada_0008.jpg
# 파일 이동 완료 : Tony_Blair_0038.jpg
# 파일 이동 완료 : Jose_Maria_Aznar_0023.jpg
# 파일 이동 완료 : Johnny_Carson_0001.jpg
# 파일 이동 완료 : Colin_Powell_0102.jpg
# 파일 이동 완료 : Faye_Wong_0001.jpg
# 파일 이동 완료 : Atal_Bihari_Vajpayee_0019.jpg
# 파일 이동 완료 : Stanley_Ho_0001.jpg
# 파일 이동 완료 : Keanu_Reeves_0010.jpg
# 파일 이동 완료 : Thomas_Gottschalk_0001.jpg
# 파일 이동 완료 : James_Cameron_0003.jpg
# 파일 이동 완료 : George_W_Bush_0396.jpg
# 파일 이동 완료 : Mahathir_Mohamad_0004.jpg
# 파일 이동 완료 : Julie_Gerberding_0007.jpg
# 파일 이동 완료 : Richard_Jewell_0001.jpg
# 파일 이동 완료 : Viara_Vike-Freiberga_0001.jpg
# 파일 이동 완료 : William_McDonough_0001.jpg
# 파일 이동 완료 : Lindsay_Benko_0001.jpg
# 파일 이동 완료 : Joan_Laporta_0007.jpg
# 파일 이동 완료 : Farouk_al-Sharaa_0001.jpg
# 파일 이동 완료 : Michele_Placido_0001.jpg
# 파일 이동 완료 : Andre_Agassi_0004.jpg
# 파일 이동 완료 : Dave_Campo_0003.jpg
# 파일 이동 완료 : Ray_Price_0001.jpg
# 파일 이동 완료 : Sylvester_Stallone_0003.jpg
# 파일 이동 완료 : Lord_Hutton_0001.jpg
# 파일 이동 완료 : Gerald_Fitch_0001.jpg
# 파일 이동 완료 : Boris_Becker_0001.jpg
# 파일 이동 완료 : Loretta_Lynn_Harper_0001.jpg
# 파일 이동 완료 : Vladimir_Putin_0037.jpg
# 파일 이동 완료 : Rebekah_Chantay_Revels_0001.jpg
# 파일 이동 완료 : Shavon_Earp_0001.jpg
# 파일 이동 완료 : George_W_Bush_0462.jpg
# 파일 이동 완료 : Hamid_Karzai_0003.jpg
# 파일 이동 완료 : Simon_Yam_0001.jpg
# 파일 이동 완료 : Taha_Yassin_Ramadan_0010.jpg
# 파일 이동 완료 : James_Schultz_0001.jpg
# 파일 이동 완료 : Roberto_Cavalli_0001.jpg
# 파일 이동 완료 : Mikhail_Wehbe_0004.jpg
# 파일 이동 완료 : Flavia_Delaroli_0001.jpg
# 파일 이동 완료 : Andre_Agassi_0018.jpg
# 파일 이동 완료 : Dominique_de_Villepin_0009.jpg
# 파일 이동 완료 : Neil_Goldman_0001.jpg
# 파일 이동 완료 : Jim_Wong_0001.jpg
# 파일 이동 완료 : Jean_Chretien_0046.jpg
# 파일 이동 완료 : Saddam_Hussein_0022.jpg
# 파일 이동 완료 : Francis_Crick_0001.jpg
# 파일 이동 완료 : Jiri_Novak_0009.jpg
# 파일 이동 완료 : George_W_Bush_0205.jpg
# 파일 이동 완료 : Qian_Qichen_0001.jpg
# 파일 이동 완료 : Mireille_Jospin-Dandieu_0001.jpg
# 파일 이동 완료 : Casey_Crowder_0001.jpg
# 파일 이동 완료 : Red_Auerbach_0001.jpg
# 파일 이동 완료 : Marc_Leger_0001.jpg
# 파일 이동 완료 : Kim_Ryong-sung_0005.jpg
# 파일 이동 완료 : Steve_Fehr_0001.jpg
# 파일 이동 완료 : David_Nalbandian_0003.jpg
# 파일 이동 완료 : Vladimir_Putin_0042.jpg
# 파일 이동 완료 : Alfred_Sant_0001.jpg
# 파일 이동 완료 : Prince_Claus_0003.jpg
# 파일 이동 완료 : Ariel_Sharon_0022.jpg
# 파일 이동 완료 : Jennifer_Aniston_0015.jpg
# 파일 이동 완료 : John_Allen_Muhammad_0006.jpg
# 파일 이동 완료 : Jean_Chretien_0047.jpg
# 파일 이동 완료 : Lou_Ye_0001.jpg
# 파일 이동 완료 : Franklin_Brown_0001.jpg
# 파일 이동 완료 : Jack_Smith_0001.jpg
# 파일 이동 완료 : Hans_Blix_0013.jpg
# 파일 이동 완료 : Jung_Bong_0001.jpg
# 파일 이동 완료 : Dominique_de_Villepin_0001.jpg
# 파일 이동 완료 : George_W_Bush_0506.jpg
# 파일 이동 완료 : Tommy_Franks_0011.jpg
# 파일 이동 완료 : Matt_LeBlanc_0001.jpg
# 파일 이동 완료 : Sean_Combs_0001.jpg
# 파일 이동 완료 : Gunter_Pleuger_0005.jpg
# 파일 이동 완료 : Dave_Lewis_0001.jpg
# 파일 이동 완료 : Kristy_Curry_0001.jpg
# 파일 이동 완료 : George_W_Bush_0254.jpg
# 파일 이동 완료 : Paul_Sarbanes_0002.jpg
# 파일 이동 완료 : Javier_Solana_0007.jpg
# 파일 이동 완료 : Matthew_Broderick_0004.jpg
# 파일 이동 완료 : Winona_Ryder_0021.jpg
# 파일 이동 완료 : Mohammed_Al-Douri_0010.jpg
# 파일 이동 완료 : Steven_Briggs_0001.jpg
# 파일 이동 완료 : Victoria_Clarke_0003.jpg
# 파일 이동 완료 : Milo_Djukanovic_0002.jpg
# 파일 이동 완료 : Mohammed_Al-Douri_0002.jpg
# 파일 이동 완료 : George_W_Bush_0476.jpg
# 파일 이동 완료 : Thomas_OBrien_0002.jpg
# 파일 이동 완료 : Takeo_Hiranuma_0001.jpg
# 파일 이동 완료 : Maureen_Fanning_0001.jpg
# 파일 이동 완료 : Gregg_Popovich_0001.jpg
# 파일 이동 완료 : Tommy_Maddox_0001.jpg
# 파일 이동 완료 : Bill_Nelson_0002.jpg
# 파일 이동 완료 : Craig_MacTavish_0001.jpg
# 파일 이동 완료 : Abdoulaye_Wade_0004.jpg
# 파일 이동 완료 : Mile_Mrksic_0001.jpg
# 파일 이동 완료 : Kristanna_Loken_0005.jpg
# 파일 이동 완료 : Norodom_Chakrapong_0001.jpg
# 파일 이동 완료 : Michelle_Pfeiffer_0002.jpg
# 파일 이동 완료 : Thomas_Rupprath_0001.jpg
# 파일 이동 완료 : Max_von_Sydow_0001.jpg
# 파일 이동 완료 : James_Coviello_0001.jpg
# 파일 이동 완료 : Wilson_Alvarez_0001.jpg
# 파일 이동 완료 : Gloria_Macapagal_Arroyo_0001.jpg
# 파일 이동 완료 : Condoleezza_Rice_0002.jpg
# 파일 이동 완료 : John_Kerry_0014.jpg
# 파일 이동 완료 : Russ_Ortiz_0001.jpg
# 파일 이동 완료 : Colin_Powell_0115.jpg
# 파일 이동 완료 : Jennifer_Capriati_0010.jpg
# 파일 이동 완료 : Pernilla_Bjorn_0001.jpg
# 파일 이동 완료 : Jean_Nagel_0001.jpg
# 파일 이동 완료 : Amelie_Mauresmo_0004.jpg
# 파일 이동 완료 : Julio_Toro_0001.jpg
# 파일 이동 완료 : Garry_Trudeau_0001.jpg
# 파일 이동 완료 : Jennifer_Lopez_0007.jpg
# 파일 이동 완료 : Pete_Sampras_0002.jpg
# 파일 이동 완료 : Tony_Blair_0004.jpg
# 파일 이동 완료 : Salma_Hayek_0005.jpg
# 파일 이동 완료 : Tiger_Woods_0020.jpg
# 파일 이동 완료 : Robert_Evans_0003.jpg
# 파일 이동 완료 : Luiz_Inacio_Lula_da_Silva_0006.jpg
# 파일 이동 완료 : Muhammad_Ali_0003.jpg
# 파일 이동 완료 : Joe_Crede_0001.jpg
# 파일 이동 완료 : Gian_Marco_0002.jpg
# 파일 이동 완료 : Jong_Wook_Lee_0004.jpg
# 파일 이동 완료 : Warren_Buffett_0001.jpg
# 파일 이동 완료 : Javier_Weber_0001.jpg
# 파일 이동 완료 : Lynn_Redgrave_0002.jpg
# 파일 이동 완료 : David_Duke_0001.jpg
# 파일 이동 완료 : George_W_Bush_0204.jpg
# 파일 이동 완료 : Mark_Philippoussis_0008.jpg
# 파일 이동 완료 : Alyson_Hannigan_0001.jpg
# 파일 이동 완료 : Leonardo_Fernandez_0001.jpg
# 파일 이동 완료 : Elizabeth_Smart_0002.jpg
# 파일 이동 완료 : Jose_Maria_Aznar_0020.jpg
# 파일 이동 완료 : Alan_Mulally_0002.jpg
# 파일 이동 완료 : Hartmut_Mehdorn_0001.jpg
# 파일 이동 완료 : Richard_Reid_0001.jpg
# 파일 이동 완료 : Barbara_Walters_0004.jpg
# 파일 이동 완료 : Dave_Johnson_0001.jpg
# 파일 이동 완료 : Lucio_Gutierrez_0006.jpg
# 파일 이동 완료 : Lisa_Marie_Presley_0004.jpg
# 파일 이동 완료 : Tiger_Woods_0023.jpg
# 파일 이동 완료 : Newton_Carlton_Slawson_0001.jpg
# 파일 이동 완료 : Eduardo_Chillida_0001.jpg
# 파일 이동 완료 : Samuel_Waksal_0001.jpg
# 파일 이동 완료 : George_Foreman_0002.jpg
# 파일 이동 완료 : Shia_LaBeouf_0002.jpg
# 파일 이동 완료 : Rod_Jong-il_0001.jpg
# 파일 이동 완료 : Antonio_Catania_0001.jpg
# 파일 이동 완료 : Jose_Luis_Santiago_Vasconcelos_0001.jpg
# 파일 이동 완료 : Iain_Anderson_0001.jpg
# 파일 이동 완료 : James_Maguire_0002.jpg
# 파일 이동 완료 : Fidel_Castro_0015.jpg
# 파일 이동 완료 : George_W_Bush_0167.jpg
# 파일 이동 완료 : Franz_Fischler_0004.jpg
# 파일 이동 완료 : Hugh_Grant_0006.jpg
# 파일 이동 완료 : Jennifer_Lopez_0008.jpg
# 파일 이동 완료 : Naomi_Watts_0001.jpg
# 파일 이동 완료 : Naomi_Watts_0022.jpg
# 파일 이동 완료 : Julian_Battle_0001.jpg
# 파일 이동 완료 : Christopher_Reeve_0001.jpg
# 파일 이동 완료 : Vaclav_Havel_0002.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0084.jpg
# 파일 이동 완료 : Mark_Gangloff_0001.jpg
# 파일 이동 완료 : Laurence_Tribe_0001.jpg
# 파일 이동 완료 : Ralf_Schumacher_0007.jpg
# 파일 이동 완료 : Calista_Flockhart_0006.jpg
# 파일 이동 완료 : George_W_Bush_0314.jpg
# 파일 이동 완료 : George_W_Bush_0040.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0051.jpg
# 파일 이동 완료 : Yoshiyuki_Kamei_0001.jpg
# 파일 이동 완료 : Derek_Parra_0001.jpg
# 파일 이동 완료 : Todd_Parrott_0001.jpg
# 파일 이동 완료 : George_W_Bush_0502.jpg
# 파일 이동 완료 : Alejandro_Toledo_0011.jpg
# 파일 이동 완료 : Guillermo_Coria_0019.jpg
# 파일 이동 완료 : Alvaro_Uribe_0022.jpg
# 파일 이동 완료 : Geoff_Hoon_0005.jpg
# 파일 이동 완료 : George_HW_Bush_0007.jpg
# 파일 이동 완료 : Sergio_Vieira_De_Mello_0011.jpg
# 파일 이동 완료 : Michael_Phelps_0004.jpg
# 파일 이동 완료 : Yoko_Ono_0001.jpg
# 파일 이동 완료 : Ben_Chandler_0001.jpg
# 파일 이동 완료 : Judi_Patton_0001.jpg
# 파일 이동 완료 : Ralf_Schumacher_0004.jpg
# 파일 이동 완료 : Colleen_Donovan_0001.jpg
# 파일 이동 완료 : David_Provost_0001.jpg
# 파일 이동 완료 : Marc_Racicot_0001.jpg
# 파일 이동 완료 : Elizabeth_Taylor_0001.jpg
# 파일 이동 완료 : George_W_Bush_0228.jpg
# 파일 이동 완료 : Ferenc_Madl_0002.jpg
# 파일 이동 완료 : Zhu_Rongji_0003.jpg
# 파일 이동 완료 : Atal_Bihari_Vajpayee_0013.jpg
# 파일 이동 완료 : Colin_Powell_0177.jpg
# 파일 이동 완료 : Tony_Blair_0007.jpg
# 파일 이동 완료 : Mel_Gibson_0001.jpg
# 파일 이동 완료 : Roger_Moore_0001.jpg
# 파일 이동 완료 : Elizabeth_Smart_0005.jpg
# 파일 이동 완료 : Jennifer_Lopez_0014.jpg
# 파일 이동 완료 : Elizabeth_Regan_0001.jpg
# 파일 이동 완료 : Gene_Robinson_0002.jpg
# 파일 이동 완료 : Theo_Angelopoulos_0001.jpg
# 파일 이동 완료 : Mikulas_Dzurinda_0001.jpg
# 파일 이동 완료 : Elinor_Caplan_0001.jpg
# 파일 이동 완료 : Robbie_Coltrane_0001.jpg
# 파일 이동 완료 : Alain_Cervantes_0001.jpg
# 파일 이동 완료 : Mahmoud_Abbas_0023.jpg
# 파일 이동 완료 : Kwame_Kilpatrick_0001.jpg
# 파일 이동 완료 : Gustavo_Kuerten_0003.jpg
# 파일 이동 완료 : Tony_Blair_0106.jpg
# 파일 이동 완료 : Hank_McKinnell_0001.jpg
# 파일 이동 완료 : Renee_Zellweger_0017.jpg
# 파일 이동 완료 : Alfonso_Cuaron_0001.jpg
# 파일 이동 완료 : Russell_Crowe_0001.jpg
# 파일 이동 완료 : Michael_Jackson_0012.jpg
# 파일 이동 완료 : Zoe_Ball_0001.jpg
# 파일 이동 완료 : Vladimir_Putin_0008.jpg
# 파일 이동 완료 : Sebastian_Porto_0001.jpg
# 파일 이동 완료 : Gloria_Macapagal_Arroyo_0023.jpg
# 파일 이동 완료 : Carolyn_Dawn_Johnson_0001.jpg
# 파일 이동 완료 : Josh_Evans_0001.jpg
# 파일 이동 완료 : Jim_Bollman_0001.jpg
# 파일 이동 완료 : Jacques_Chirac_0034.jpg
# 파일 이동 완료 : George_W_Bush_0239.jpg
# 파일 이동 완료 : Adam_Sandler_0004.jpg
# 파일 이동 완료 : Harvey_Wachsman_0001.jpg
# 파일 이동 완료 : Donald_Evans_0001.jpg
# 파일 이동 완료 : Hank_Aaron_0001.jpg
# 파일 이동 완료 : Jiang_Zemin_0011.jpg
# 파일 이동 완료 : Adrien_Brody_0006.jpg
# 파일 이동 완료 : George_W_Bush_0093.jpg
# 파일 이동 완료 : Peter_Mansbridge_0001.jpg
# 파일 이동 완료 : Mark_Broxmeyer_0001.jpg
# 파일 이동 완료 : Maria_Bello_0001.jpg
# 파일 이동 완료 : Mary_Lou_Markakis_0001.jpg
# 파일 이동 완료 : Yoriko_Kawaguchi_0012.jpg
# 파일 이동 완료 : Ingrid_Betancourt_0001.jpg
# 파일 이동 완료 : Anne_Krueger_0002.jpg
# 파일 이동 완료 : Lindsay_Davenport_0014.jpg
# 파일 이동 완료 : Li_Zhaoxing_0001.jpg
# 파일 이동 완료 : George_Ryan_0004.jpg
# 파일 이동 완료 : Jacob_Frenkel_0001.jpg
# 파일 이동 완료 : Tommy_Franks_0009.jpg
# 파일 이동 완료 : Wen_Jiabao_0012.jpg
# 파일 이동 완료 : Roh_Moo-hyun_0020.jpg
# 파일 이동 완료 : Celine_Dion_0005.jpg
# 파일 이동 완료 : Jackie_Chan_0007.jpg
# 파일 이동 완료 : Ron_Dittemore_0003.jpg
# 파일 이동 완료 : Jennifer_Lopez_0015.jpg
# 파일 이동 완료 : Richard_Gere_0004.jpg
# 파일 이동 완료 : Oleksandr_Moroz_0001.jpg
# 파일 이동 완료 : Fernando_Hierro_0001.jpg
# 파일 이동 완료 : Atsushi_Sato_0001.jpg
# 파일 이동 완료 : Ai_Sugiyama_0005.jpg
# 파일 이동 완료 : Cori_Enghusen_0001.jpg
# 파일 이동 완료 : Takenori_Kanzaki_0001.jpg
# 파일 이동 완료 : Paul_Martin_0006.jpg
# 파일 이동 완료 : Allyson_Felix_0002.jpg
# 파일 이동 완료 : Cathy_Chisholm_0001.jpg
# 파일 이동 완료 : James_Blake_0013.jpg
# 파일 이동 완료 : Mohammed_Al-Douri_0001.jpg
# 파일 이동 완료 : Jean_Chretien_0032.jpg
# 파일 이동 완료 : Osama_bin_Laden_0002.jpg
# 파일 이동 완료 : Princess_Anne_0002.jpg
# 파일 이동 완료 : George_W_Bush_0347.jpg
# 파일 이동 완료 : George_W_Bush_0311.jpg
# 파일 이동 완료 : Tabare_Vazquez_0001.jpg
# 파일 이동 완료 : Augustin_Calleri_0001.jpg
# 파일 이동 완료 : George_W_Bush_0385.jpg
# 파일 이동 완료 : Jeong_Se-hyun_0005.jpg
# 파일 이동 완료 : Jacques_Chirac_0011.jpg
# 파일 이동 완료 : Recep_Tayyip_Erdogan_0011.jpg
# 파일 이동 완료 : Kate_Hudson_0008.jpg
# 파일 이동 완료 : Spencer_Abraham_0014.jpg
# 파일 이동 완료 : Hans_Blix_0024.jpg
# 파일 이동 완료 : Peter_Fitzgerald_0001.jpg
# 파일 이동 완료 : Giuseppe_Gibilisco_0003.jpg
# 파일 이동 완료 : Terry_Hoeppner_0001.jpg
# 파일 이동 완료 : Camille_Colvin_0001.jpg
# 파일 이동 완료 : Bijan_Namdar_Zangeneh_0002.jpg
# 파일 이동 완료 : Nick_Nolte_0001.jpg
# 파일 이동 완료 : Alvaro_Silva_Calderon_0004.jpg
# 파일 이동 완료 : Kevin_Millwood_0001.jpg
# 파일 이동 완료 : Jerry_Springer_0003.jpg
# 파일 이동 완료 : Jose_Manuel_Durao_Barroso_0001.jpg
# 파일 이동 완료 : Mia_Mottley_0001.jpg
# 파일 이동 완료 : Bo_Pelini_0002.jpg
# 파일 이동 완료 : Edward_Lu_0004.jpg
# 파일 이동 완료 : George_W_Bush_0231.jpg
# 파일 이동 완료 : Prince_Willem-Alexander_0003.jpg
# 파일 이동 완료 : Nestor_Kirchner_0018.jpg
# 파일 이동 완료 : Alejandro_Lembo_0001.jpg
# 파일 이동 완료 : Luis_Horna_0003.jpg
# 파일 이동 완료 : Hugo_Chavez_0046.jpg
# 파일 이동 완료 : Marcelo_Salas_0003.jpg
# 파일 이동 완료 : Rick_Perry_0006.jpg
# 파일 이동 완료 : Andy_Roddick_0013.jpg
# 파일 이동 완료 : Hans_Peter_Briegel_0001.jpg
# 파일 이동 완료 : Colin_Powell_0205.jpg
# 파일 이동 완료 : George_W_Bush_0432.jpg
# 파일 이동 완료 : Jean_Carnahan_0001.jpg
# 파일 이동 완료 : George_Robertson_0013.jpg
# 파일 이동 완료 : Amanda_Marsh_0001.jpg
# 파일 이동 완료 : Taylyn_Solomon_0001.jpg
# 파일 이동 완료 : Meryl_Streep_0007.jpg
# 파일 이동 완료 : Meryl_Streep_0011.jpg
# 파일 이동 완료 : Begum_Khaleda_Zia_0001.jpg
# 파일 이동 완료 : Robbie_Mc_Ewen_0001.jpg
# 파일 이동 완료 : Hamid_Karzai_0007.jpg
# 파일 이동 완료 : Antony_Leung_0001.jpg
# 파일 이동 완료 : Ryan_Drese_0001.jpg
# 파일 이동 완료 : Angelina_Jolie_0014.jpg
# 파일 이동 완료 : Donatella_Versace_0002.jpg
# 파일 이동 완료 : Paul_Otellini_0001.jpg
# 파일 이동 완료 : Carlos_De_Abreu_0001.jpg
# 파일 이동 완료 : Sara_Silverman_0001.jpg
# 파일 이동 완료 : Martin_Gecht_0001.jpg
# 파일 이동 완료 : Hosni_Mubarak_0002.jpg
# 파일 이동 완료 : Amanda_Bynes_0001.jpg
# 파일 이동 완료 : Hu_Jintao_0008.jpg
# 파일 이동 완료 : Jean-Pierre_Bemba_0001.jpg
# 파일 이동 완료 : George_W_Bush_0215.jpg
# 파일 이동 완료 : Marisa_Tomei_0002.jpg
# 파일 이동 완료 : Jon_Corzine_0003.jpg
# 파일 이동 완료 : Charlie_Hunnam_0001.jpg
# 파일 이동 완료 : Colin_Powell_0039.jpg
# 파일 이동 완료 : Rita_Wilson_0001.jpg
# 파일 이동 완료 : Stanley_Nelson_0001.jpg
# 파일 이동 완료 : Rupert_Murdoch_0001.jpg
# 파일 이동 완료 : Heizo_Takenaka_0008.jpg
# 파일 이동 완료 : John_Bolton_0008.jpg
# 파일 이동 완료 : Larry_Coker_0002.jpg
# 파일 이동 완료 : Yoriko_Kawaguchi_0001.jpg
# 파일 이동 완료 : Tony_Blair_0141.jpg
# 파일 이동 완료 : Martin_Burnham_0001.jpg
# 파일 이동 완료 : John_Swofford_0001.jpg
# 파일 이동 완료 : Rita_Moreno_0001.jpg
# 파일 이동 완료 : Mikhail_Youzhny_0003.jpg
# 파일 이동 완료 : Osmond_Smith_0001.jpg
# 파일 이동 완료 : Bob_Hartley_0001.jpg
# 파일 이동 완료 : Vincent_Brooks_0003.jpg
# 파일 이동 완료 : Paula_Dobriansky_0001.jpg
# 파일 이동 완료 : Shirley_Jones_0001.jpg
# 파일 이동 완료 : Mike_Helton_0002.jpg
# 파일 이동 완료 : Paul_Wolfowitz_0010.jpg
# 파일 이동 완료 : Francis_Ricciardone_0001.jpg
# 파일 이동 완료 : Alejandro_Toledo_0019.jpg
# 파일 이동 완료 : George_W_Bush_0092.jpg
# 파일 이동 완료 : John_Negroponte_0031.jpg
# 파일 이동 완료 : Antony_Leung_0003.jpg
# 파일 이동 완료 : James_Layug_0001.jpg
# 파일 이동 완료 : David_Beckham_0015.jpg
# 파일 이동 완료 : Raymond_Odierno_0002.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0032.jpg
# 파일 이동 완료 : Tom_Ridge_0027.jpg
# 파일 이동 완료 : Christy_Ferer_0001.jpg
# 파일 이동 완료 : Jean_Charest_0015.jpg
# 파일 이동 완료 : Colin_Powell_0061.jpg
# 파일 이동 완료 : Alisha_Richman_0001.jpg
# 파일 이동 완료 : Daja_Bedanova_0001.jpg
# 파일 이동 완료 : Robert_Mugabe_0001.jpg
# 파일 이동 완료 : Richie_Adubato_0001.jpg
# 파일 이동 완료 : Ben_Wallace_0001.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0044.jpg
# 파일 이동 완료 : Jonathan_Edwards_0002.jpg
# 파일 이동 완료 : Muhammad_Ibrahim_Bilal_0001.jpg
# 파일 이동 완료 : George_W_Bush_0496.jpg
# 파일 이동 완료 : Vicente_Fox_0019.jpg
# 파일 이동 완료 : George_W_Bush_0048.jpg
# 파일 이동 완료 : Lionel_Chalmers_0001.jpg
# 파일 이동 완료 : Margaret_Hoelzer_0001.jpg
# 파일 이동 완료 : Rita_Wilson_0002.jpg
# 파일 이동 완료 : Morris_Dees_0001.jpg
# 파일 이동 완료 : Marcelo_Rios_0004.jpg
# 파일 이동 완료 : Bruce_Springsteen_0003.jpg
# 파일 이동 완료 : Nicole_Kidman_0015.jpg
# 파일 이동 완료 : Eva_Amurri_0001.jpg
# 파일 이동 완료 : Federico_Trillo_0001.jpg
# 파일 이동 완료 : Ismail_Merchant_0001.jpg
# 파일 이동 완료 : Job_Cohen_0001.jpg
# 파일 이동 완료 : George_W_Bush_0354.jpg
# 파일 이동 완료 : Bill_Clinton_0018.jpg
# 파일 이동 완료 : Grant_Hackett_0003.jpg
# 파일 이동 완료 : Norman_Jewison_0002.jpg
# 파일 이동 완료 : Richard_Tubb_0001.jpg
# 파일 이동 완료 : Jason_Kidd_0010.jpg
# 파일 이동 완료 : Hassan_Wirajuda_0002.jpg
# 파일 이동 완료 : Al_Gore_0005.jpg
# 파일 이동 완료 : Doris_Schroeder_0002.jpg
# 파일 이동 완료 : John_Snow_0011.jpg
# 파일 이동 완료 : Steve_Nash_0001.jpg
# 파일 이동 완료 : Kamal_Kharrazi_0001.jpg
# 파일 이동 완료 : George_W_Bush_0145.jpg
# 파일 이동 완료 : Arnold_Schwarzenegger_0015.jpg
# 파일 이동 완료 : Leland_Chapman_0001.jpg
# 파일 이동 완료 : Hu_Jintao_0005.jpg
# 파일 이동 완료 : Binyamin_Ben-Eliezer_0003.jpg
# 파일 이동 완료 : Sun_Myung_Moon_0001.jpg
# 파일 이동 완료 : Bill_Clinton_0013.jpg
# 파일 이동 완료 : Elton_John_0001.jpg
# 파일 이동 완료 : Kristanna_Loken_0002.jpg
# 파일 이동 완료 : Abdullah_Ahmad_Badawi_0001.jpg
# 파일 이동 완료 : Mike_Carona_0001.jpg
# 파일 이동 완료 : Danis_Tanovic_0001.jpg
# 파일 이동 완료 : Giannina_Facio_0001.jpg
# 파일 이동 완료 : Taha_Yassin_Ramadan_0007.jpg
# 파일 이동 완료 : Jorge_Valdano_0002.jpg
# 파일 이동 완료 : Armando_Avila_Panchame_0001.jpg
# 파일 이동 완료 : Kofi_Annan_0030.jpg
# 파일 이동 완료 : Jim_Tressel_0002.jpg
# 파일 이동 완료 : George_W_Bush_0061.jpg
# 파일 이동 완료 : Winona_Ryder_0015.jpg
# 파일 이동 완료 : Mohamed_Seineldin_0001.jpg
# 파일 이동 완료 : Sylvia_Plachy_0001.jpg
# 파일 이동 완료 : Cameron_Diaz_0006.jpg
# 파일 이동 완료 : Brenda_Wilson_0001.jpg
# 파일 이동 완료 : Rob_Marshall_0004.jpg
# 파일 이동 완료 : Hans_Blix_0014.jpg
# 파일 이동 완료 : John_White_0001.jpg
# 파일 이동 완료 : Arnold_Schwarzenegger_0039.jpg
# 파일 이동 완료 : Sean_Townsend_0001.jpg
# 파일 이동 완료 : Clint_Eastwood_0006.jpg
# 파일 이동 완료 : Jerry_Tarkanian_0001.jpg
# 파일 이동 완료 : John_Edwards_0008.jpg
# 파일 이동 완료 : Colin_Powell_0098.jpg
# 파일 이동 완료 : Calvin_Joseph_Coleman_0001.jpg
# 파일 이동 완료 : Elizabeth_Berkeley_0001.jpg
# 파일 이동 완료 : Mariah_Carey_0003.jpg
# 파일 이동 완료 : Craig_Fitzgibbon_0001.jpg
# 파일 이동 완료 : Chok_Tong_Goh_0002.jpg
# 파일 이동 완료 : Chin-Feng_Chen_0001.jpg
# 파일 이동 완료 : Andre_Bucher_0001.jpg
# 파일 이동 완료 : Yu_Shyi-kun_0003.jpg
# 파일 이동 완료 : Robert_Gordon_Card_0001.jpg
# 파일 이동 완료 : Wolfgang_Schuessel_0003.jpg
# 파일 이동 완료 : John_Wright_0001.jpg
# 파일 이동 완료 : Lance_Armstrong_0011.jpg
# 파일 이동 완료 : Tommy_Thompson_0003.jpg
# 파일 이동 완료 : Heizo_Takenaka_0004.jpg
# 파일 이동 완료 : Adrien_Brody_0001.jpg
# 파일 이동 완료 : Tono_Suratman_0001.jpg
# 파일 이동 완료 : Pierce_Brosnan_0004.jpg
# 파일 이동 완료 : Juanes_0001.jpg
# 파일 이동 완료 : Earl_Scruggs_0001.jpg
# 파일 이동 완료 : Patricia_Clarkson_0003.jpg
# 파일 이동 완료 : George_W_Bush_0440.jpg
# 파일 이동 완료 : Richard_Lennon_0001.jpg
# 파일 이동 완료 : Gary_Winnick_0001.jpg
# 파일 이동 완료 : Juan_Pablo_Montoya_0004.jpg
# 파일 이동 완료 : Dustan_Mohr_0001.jpg
# 파일 이동 완료 : Bettina_Rheims_0001.jpg
# 파일 이동 완료 : George_W_Bush_0371.jpg
# 파일 이동 완료 : Juan_Carlos_Morales_0001.jpg
# 파일 이동 완료 : Scott_Peterson_0001.jpg
# 파일 이동 완료 : Luis_Figo_0003.jpg
# 파일 이동 완료 : Jan_Peter_Balkenende_0001.jpg
# 파일 이동 완료 : Meles_Zenawi_0001.jpg
# 파일 이동 완료 : Shimon_Peres_0008.jpg
# 파일 이동 완료 : Adrian_Annus_0001.jpg
# 파일 이동 완료 : Colin_Powell_0076.jpg
# 파일 이동 완료 : Isaiah_Washington_0002.jpg
# 파일 이동 완료 : George_W_Bush_0059.jpg
# 파일 이동 완료 : Keith_Foulke_0001.jpg
# 파일 이동 완료 : Yukio_Hatoyama_0001.jpg
# 파일 이동 완료 : Hugo_Chavez_0066.jpg
# 파일 이동 완료 : Laura_Ziskin_0001.jpg
# 파일 이동 완료 : Alberto_Fujimori_0002.jpg
# 파일 이동 완료 : Robert_Duvall_0001.jpg
# 파일 이동 완료 : Sandra_Bullock_0001.jpg
# 파일 이동 완료 : Gerhard_Boekel_0001.jpg
# 파일 이동 완료 : David_Suazo_0001.jpg
# 파일 이동 완료 : William_Ford_Jr_0006.jpg
# 파일 이동 완료 : Melana_Scantlin_0001.jpg
# 파일 이동 완료 : Filippo_Inzaghi_0002.jpg
# 파일 이동 완료 : Jeremy_Greenstock_0011.jpg
# 파일 이동 완료 : Chung_Mong-hun_0002.jpg
# 파일 이동 완료 : Tom_Daschle_0002.jpg
# 파일 이동 완료 : Susan_Walvius_0001.jpg
# 파일 이동 완료 : Anastasia_Kelesidou_0001.jpg
# 파일 이동 완료 : Luis_Figo_0002.jpg
# 파일 이동 완료 : Ashlea_Talbot_0001.jpg
# 파일 이동 완료 : Michael_Jackson_0005.jpg
# 파일 이동 완료 : Bak_Chang-Ryun_0001.jpg
# 파일 이동 완료 : Jacques_Chirac_0037.jpg
# 파일 이동 완료 : Alvaro_Uribe_0009.jpg
# 파일 이동 완료 : Colin_Powell_0094.jpg
# 파일 이동 완료 : Heinz_Feldmann_0002.jpg
# 파일 이동 완료 : Julia_Tymoshenko_0001.jpg
# 파일 이동 완료 : Dick_Vermeil_0001.jpg
# 파일 이동 완료 : John_Howard_0001.jpg
# 파일 이동 완료 : Phil_Gramm_0001.jpg
# 파일 이동 완료 : Tommy_Thompson_0006.jpg
# 파일 이동 완료 : Hans_Blix_0010.jpg
# 파일 이동 완료 : Rubens_Barrichello_0012.jpg
# 파일 이동 완료 : Herta_Daeubler-Gmelin_0002.jpg
# 파일 이동 완료 : John_Paul_II_0003.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0080.jpg
# 파일 이동 완료 : Hu_Jintao_0009.jpg
# 파일 이동 완료 : Clara_Harris_0002.jpg
# 파일 이동 완료 : George_Lopez_0005.jpg
# 파일 이동 완료 : Nia_Vardalos_0003.jpg
# 파일 이동 완료 : Prince_Charles_0005.jpg
# 파일 이동 완료 : Zarai_Toledo_0002.jpg
# 파일 이동 완료 : James_McGreevey_0001.jpg
# 파일 이동 완료 : Colin_Powell_0184.jpg
# 파일 이동 완료 : Saburo_Kawabuchi_0002.jpg
# 파일 이동 완료 : Ben_Curtis_0003.jpg
# 파일 이동 완료 : Jim_Nochols_0001.jpg
# 파일 이동 완료 : Jennifer_Rodriguez_0001.jpg
# 파일 이동 완료 : Brad_Johnson_0005.jpg
# 파일 이동 완료 : Hans_Blix_0033.jpg
# 파일 이동 완료 : Nathalia_Gillot_0001.jpg
# 파일 이동 완료 : King_Abdullah_II_0003.jpg
# 파일 이동 완료 : Akbar_Hashemi_Rafsanjani_0003.jpg
# 파일 이동 완료 : Roy_Jones_Jr_0001.jpg
# 파일 이동 완료 : Colin_Powell_0125.jpg
# 파일 이동 완료 : Michael_Douglas_0004.jpg
# 파일 이동 완료 : Steffi_Graf_0003.jpg
# 파일 이동 완료 : Vladimir_Putin_0012.jpg
# 파일 이동 완료 : Julianna_Margulies_0002.jpg
# 파일 이동 완료 : Zeng_Qinghong_0001.jpg
# 파일 이동 완료 : Maria_Sanchez_Lorenzo_0001.jpg
# 파일 이동 완료 : Alistair_MacDonald_0001.jpg
# 파일 이동 완료 : Reggie_Miller_0002.jpg
# 파일 이동 완료 : Teresa_Worbis_0001.jpg
# 파일 이동 완료 : Bobby_Robson_0001.jpg
# 파일 이동 완료 : Edward_Kennedy_0001.jpg
# 파일 이동 완료 : Hanns_Schumacher_0001.jpg
# 파일 이동 완료 : Christina_Aguilera_0002.jpg
# 파일 이동 완료 : Serena_Williams_0038.jpg
# 파일 이동 완료 : Monique_Garbrecht-Enfeldt_0001.jpg
# 파일 이동 완료 : Zinedine_Zidane_0003.jpg
# 파일 이동 완료 : Alejandro_Avila_0003.jpg
# 파일 이동 완료 : Amelie_Mauresmo_0017.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0078.jpg
# 파일 이동 완료 : Camryn_Manheim_0001.jpg
# 파일 이동 완료 : David_Beckham_0014.jpg
# 파일 이동 완료 : Mary_Jo_Myers_0001.jpg
# 파일 이동 완료 : Joseph_Kabila_0001.jpg
# 파일 이동 완료 : Jerry_Falwell_0002.jpg
# 파일 이동 완료 : George_W_Bush_0006.jpg
# 파일 이동 완료 : Vladimir_Putin_0028.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0083.jpg
# 파일 이동 완료 : Mark_Warner_0002.jpg
# 파일 이동 완료 : Steve_Zahn_0001.jpg
# 파일 이동 완료 : Rob_Lowe_0003.jpg
# 파일 이동 완료 : Andre_Agassi_0021.jpg
# 파일 이동 완료 : Nicanor_Duarte_Frutos_0008.jpg
# 파일 이동 완료 : Mary_Anne_Souza_0001.jpg
# 파일 이동 완료 : Wolfgang_Schuessel_0001.jpg
# 파일 이동 완료 : Rick_Wagoner_0002.jpg
# 파일 이동 완료 : Ralf_Schumacher_0006.jpg
# 파일 이동 완료 : Greg_Kinsey_0001.jpg
# 파일 이동 완료 : Ian_Thorpe_0002.jpg
# 파일 이동 완료 : Askar_Akayev_0001.jpg
# 파일 이동 완료 : Fernando_Henrique_Cardoso_0001.jpg
# 파일 이동 완료 : Enrik_Vendt_0001.jpg
# 파일 이동 완료 : Mark_Hamister_0002.jpg
# 파일 이동 완료 : Michael_Fitzgerald_0001.jpg
# 파일 이동 완료 : George_W_Bush_0477.jpg
# 파일 이동 완료 : Stephane_Rochon_0001.jpg
# 파일 이동 완료 : Pervez_Musharraf_0012.jpg
# 파일 이동 완료 : Trent_Lott_0011.jpg
# 파일 이동 완료 : Angelo_Reyes_0004.jpg
# 파일 이동 완료 : Carla_Del_Ponte_0002.jpg
# 파일 이동 완료 : Placido_Domingo_0002.jpg
# 파일 이동 완료 : David_Stern_0003.jpg
# 파일 이동 완료 : John_Howard_0011.jpg
# 파일 이동 완료 : Noer_Muis_0001.jpg
# 파일 이동 완료 : Hugo_Chavez_0063.jpg
# 파일 이동 완료 : Gloria_Macapagal_Arroyo_0034.jpg
# 파일 이동 완료 : Fidel_Castro_Daiz-Balart_0001.jpg
# 파일 이동 완료 : Tommy_Thompson_0002.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0023.jpg
# 파일 이동 완료 : George_W_Bush_0175.jpg
# 파일 이동 완료 : Charlton_Heston_0006.jpg
# 파일 이동 완료 : Luis_Figo_0004.jpg
# 파일 이동 완료 : Lance_Armstrong_0010.jpg
# 파일 이동 완료 : Ronald_Ito_0001.jpg
# 파일 이동 완료 : Paul_Tagliabue_0002.jpg
# 파일 이동 완료 : Mahmoud_Abbas_0028.jpg
# 파일 이동 완료 : Lleyton_Hewitt_0026.jpg
# 파일 이동 완료 : Steve_Avery_0001.jpg
# 파일 이동 완료 : Kirsten_Gilham_0001.jpg
# 파일 이동 완료 : Juan_Valencia_Osorio_0002.jpg
# 파일 이동 완료 : George_W_Bush_0340.jpg
# 파일 이동 완료 : Anthony_LaPaglia_0002.jpg
# 파일 이동 완료 : Pedro_Malan_0001.jpg
# 파일 이동 완료 : David_Nalbandian_0008.jpg
# 파일 이동 완료 : John_Ashcroft_0033.jpg
# 파일 이동 완료 : Jean-Francois_Pontal_0003.jpg
# 파일 이동 완료 : Nicanor_Duarte_Frutos_0001.jpg
# 파일 이동 완료 : Gloria_Macapagal_Arroyo_0024.jpg
# 파일 이동 완료 : Serena_Williams_0028.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0020.jpg
# 파일 이동 완료 : Mary_Carey_0004.jpg
# 파일 이동 완료 : Rafael_Ramirez_0001.jpg
# 파일 이동 완료 : Larry_Thompson_0002.jpg
# 파일 이동 완료 : Lleyton_Hewitt_0031.jpg
# 파일 이동 완료 : Christopher_Patten_0002.jpg
# 파일 이동 완료 : Sereyvuth_Kem_0001.jpg
# 파일 이동 완료 : Hugo_Chavez_0071.jpg
# 파일 이동 완료 : Griffin_Colvin_0001.jpg
# 파일 이동 완료 : Tim_Henman_0012.jpg
# 파일 이동 완료 : Allison_Janney_0002.jpg
# 파일 이동 완료 : George_W_Bush_0015.jpg
# 파일 이동 완료 : Fernando_Henrique_Cardoso_0006.jpg
# 파일 이동 완료 : Garry_Kasparov_0002.jpg
# 파일 이동 완료 : Andre_Agassi_0007.jpg
# 파일 이동 완료 : Jerry_Colangelo_0001.jpg
# 파일 이동 완료 : Gerald_Barbarito_0001.jpg
# 파일 이동 완료 : Benazir_Bhutto_0002.jpg
# 파일 이동 완료 : Mark_Stuart_0001.jpg
# 파일 이동 완료 : Javier_Solana_0005.jpg
# 파일 이동 완료 : Bill_Clinton_0023.jpg
# 파일 이동 완료 : Christian_Longo_0002.jpg
# 파일 이동 완료 : Carolina_Barco_0001.jpg
# 파일 이동 완료 : Colin_Campbell_0001.jpg
# 파일 이동 완료 : Carmen_Electra_0006.jpg
# 파일 이동 완료 : Tim_Welsh_0001.jpg
# 파일 이동 완료 : Robert_Redford_0003.jpg
# 파일 이동 완료 : Raul_Rivero_0001.jpg
# 파일 이동 완료 : Alejandro_Fernandez_0001.jpg
# 파일 이동 완료 : Fabrice_Santoro_0001.jpg
# 파일 이동 완료 : Leander_Paes_0002.jpg
# 파일 이동 완료 : Paul_Luvera_0001.jpg
# 파일 이동 완료 : Pervez_Musharraf_0011.jpg
# 파일 이동 완료 : Diego_Colorado_0001.jpg
# 파일 이동 완료 : Erick_Barkley_0001.jpg
# 파일 이동 완료 : Alicia_Witt_0001.jpg
# 파일 이동 완료 : Michael_Arif_0001.jpg
# 파일 이동 완료 : Megawati_Sukarnoputri_0029.jpg
# 파일 이동 완료 : Hosni_Mubarak_0004.jpg
# 파일 이동 완료 : Jeremy_Greenstock_0015.jpg
# 파일 이동 완료 : Steve_Park_0002.jpg
# 파일 이동 완료 : Tom_Watson_0002.jpg
# 파일 이동 완료 : Eliane_Karp_0002.jpg
# 파일 이동 완료 : Jacques_Rogge_0006.jpg
# 파일 이동 완료 : John_Allen_Muhammad_0005.jpg
# 파일 이동 완료 : Mahathir_Mohamad_0012.jpg
# 파일 이동 완료 : Jennifer_Capriati_0023.jpg
# 파일 이동 완료 : Eduardo_Duhalde_0008.jpg
# 파일 이동 완료 : Angela_Merkel_0002.jpg
# 파일 이동 완료 : Lawrence_Roberts_0001.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0031.jpg
# 파일 이동 완료 : Steve_Nash_0002.jpg
# 파일 이동 완료 : Rick_Dinse_0003.jpg
# 파일 이동 완료 : Marina_Hands_0001.jpg
# 파일 이동 완료 : Britney_Spears_0006.jpg
# 파일 이동 완료 : George_W_Bush_0442.jpg
# 파일 이동 완료 : Colin_Powell_0128.jpg
# 파일 이동 완료 : Nestor_Kirchner_0005.jpg
# 파일 이동 완료 : Abel_Pacheco_0003.jpg
# 파일 이동 완료 : Pedro_Solbes_0002.jpg
# 파일 이동 완료 : George_Voinovich_0002.jpg
# 파일 이동 완료 : Pamela_Anderson_0004.jpg
# 파일 이동 완료 : Mahmoud_Abbas_0014.jpg
# 파일 이동 완료 : Kofi_Annan_0017.jpg
# 파일 이동 완료 : Queen_Elizabeth_II_0011.jpg
# 파일 이동 완료 : Steffi_Graf_0004.jpg
# 파일 이동 완료 : Billy_Crawford_0001.jpg
# 파일 이동 완료 : Aretha_Franklin_0001.jpg
# 파일 이동 완료 : Gilberto_Rodriguez_Orejuela_0004.jpg
# 파일 이동 완료 : Abdullah_Gul_0017.jpg
# 파일 이동 완료 : Gloria_Macapagal_Arroyo_0026.jpg
# 파일 이동 완료 : Nestor_Kirchner_0026.jpg
# 파일 이동 완료 : Rainer_Schuettler_0002.jpg
# 파일 이동 완료 : Yuri_Fedotov_0002.jpg
# 파일 이동 완료 : Ian_Huntley_0001.jpg
# 파일 이동 완료 : Keanu_Reeves_0001.jpg
# 파일 이동 완료 : Cathryn_Crawford_0001.jpg
# 파일 이동 완료 : Derek_Lowe_0001.jpg
# 파일 이동 완료 : Mukesh_Ambani_0002.jpg
# 파일 이동 완료 : Colin_Powell_0171.jpg
# 파일 이동 완료 : Colin_Powell_0085.jpg
# 파일 이동 완료 : Joe_Calzaghe_0001.jpg
# 파일 이동 완료 : Sandy_Smith_0001.jpg
# 파일 이동 완료 : Jack_Straw_0022.jpg
# 파일 이동 완료 : Jeff_Van_Gundy_0002.jpg
# 파일 이동 완료 : Mitchell_Daniels_0001.jpg
# 파일 이동 완료 : Mike_Babcock_0002.jpg
# 파일 이동 완료 : Ben_Broussard_0001.jpg
# 파일 이동 완료 : Rob_Marshall_0005.jpg
# 파일 이동 완료 : George_Robertson_0007.jpg
# 파일 이동 완료 : Emanuel_Ginobili_0001.jpg
# 파일 이동 완료 : Gray_Davis_0004.jpg
# 파일 이동 완료 : Rainer_Schuettler_0003.jpg
# 파일 이동 완료 : Larry_Brown_0005.jpg
# 파일 이동 완료 : Sean_Penn_0003.jpg
# 파일 이동 완료 : Felix_Mantilla_0001.jpg
# 파일 이동 완료 : Carlos_Beltran_0001.jpg
# 파일 이동 완료 : Paulo_Cesar_Pinheiro_0002.jpg
# 파일 이동 완료 : Nestor_Kirchner_0021.jpg
# 파일 이동 완료 : Hichiro_Naemura_0002.jpg
# 파일 이동 완료 : John_Ashcroft_0001.jpg
# 파일 이동 완료 : Mike_Webster_0001.jpg
# 파일 이동 완료 : Daniel_Day-Lewis_0003.jpg
# 파일 이동 완료 : Silvio_Berlusconi_0017.jpg
# 파일 이동 완료 : John_Negroponte_0012.jpg
# 파일 이동 완료 : Nestor_Kirchner_0003.jpg
# 파일 이동 완료 : Abdullah_Gul_0004.jpg
# 파일 이동 완료 : George_W_Bush_0305.jpg
# 파일 이동 완료 : Mary_McCarty_0001.jpg
# 파일 이동 완료 : Gerry_Adams_0006.jpg
# 파일 이동 완료 : Amram_Mitzna_0002.jpg
# 파일 이동 완료 : Mahendra_Chaudhry_0001.jpg
# 파일 이동 완료 : Ruth_Harlow_0001.jpg
# 파일 이동 완료 : Lance_Bass_0003.jpg
# 파일 이동 완료 : Rogerio_Romero_0001.jpg
# 파일 이동 완료 : Bill_Gates_0005.jpg
# 파일 이동 완료 : Hubert_Green_0001.jpg
# 파일 이동 완료 : Begum_Khaleda_Zia_0002.jpg
# 파일 이동 완료 : Rick_Barnes_0002.jpg
# 파일 이동 완료 : Dan_Dickau_0001.jpg
# 파일 이동 완료 : Jose_Acasuso_0001.jpg
# 파일 이동 완료 : Britney_Spears_0002.jpg
# 파일 이동 완료 : Jacques_Chirac_0016.jpg
# 파일 이동 완료 : Princess_Elisabeth_0001.jpg
# 파일 이동 완료 : Ataollah_Mohajerani_0001.jpg
# 파일 이동 완료 : Janela_Jara_0001.jpg
# 파일 이동 완료 : Sofia_Milos_0001.jpg
# 파일 이동 완료 : Tim_Henman_0007.jpg
# 파일 이동 완료 : Bill_Gates_0017.jpg
# 파일 이동 완료 : David_Beckham_0016.jpg
# 파일 이동 완료 : Yoon_Jin-Sik_0001.jpg
# 파일 이동 완료 : Jorge_Moreno_0001.jpg
# 파일 이동 완료 : Roberto_Carlos_0002.jpg
# 파일 이동 완료 : Clint_Eastwood_0002.jpg
# 파일 이동 완료 : George_W_Bush_0227.jpg
# 파일 이동 완료 : Hector_Babenco_0003.jpg
# 파일 이동 완료 : Jorma_Huhtala_0001.jpg
# 파일 이동 완료 : Corey_Maggette_0001.jpg
# 파일 이동 완료 : Makiya_Ali_Hassan_0001.jpg
# 파일 이동 완료 : Chang_Saio-yue_0001.jpg
# 파일 이동 완료 : Jose_Miguel_Aleman_0001.jpg
# 파일 이동 완료 : Jennifer_Thompson_0002.jpg
# 파일 이동 완료 : Ariel_Sharon_0060.jpg
# 파일 이동 완료 : Michael_Bloomberg_0009.jpg
# 파일 이동 완료 : Saddam_Hussein_0019.jpg
# 파일 이동 완료 : Ramiro_Goben_Reducindo_0001.jpg
# 파일 이동 완료 : Arminio_Fraga_0001.jpg
# 파일 이동 완료 : Michael_Weiss_0001.jpg
# 파일 이동 완료 : Orlando_Bloom_0003.jpg
# 파일 이동 완료 : Noelle_Bush_0002.jpg
# 파일 이동 완료 : Ciro_Gomes_0004.jpg
# 파일 이동 완료 : Jacques_Chirac_0025.jpg
# 파일 이동 완료 : Harrison_Ford_0004.jpg
# 파일 이동 완료 : King_Abdullah_II_0002.jpg
# 파일 이동 완료 : Julianne_Moore_0008.jpg
# 파일 이동 완료 : Kevin_Satterfield_0001.jpg
# 파일 이동 완료 : Gonzalo_Sanchez_de_Lozada_0012.jpg
# 파일 이동 완료 : Tony_Blair_0090.jpg
# 파일 이동 완료 : Mikhail_Khodorkovsky_0001.jpg
# 파일 이동 완료 : Johnny_Benson_0001.jpg
# 파일 이동 완료 : Rod_Stewart_0001.jpg
# 파일 이동 완료 : Bulent_Ecevit_0002.jpg
# 파일 이동 완료 : Rolf_Eckrodt_0001.jpg
# 파일 이동 완료 : Kim_Chinn_0001.jpg
# 파일 이동 완료 : Yoon_Jeong_Cho_0001.jpg
# 파일 이동 완료 : Justine_Pasek_0006.jpg
# 파일 이동 완료 : Pascal_Affi_Nguessan_0001.jpg
# 파일 이동 완료 : John_Petty_0001.jpg
# 파일 이동 완료 : Ferenc_Madl_0001.jpg
# 파일 이동 완료 : Hilary_Duff_0002.jpg
# 파일 이동 완료 : Alex_Barros_0002.jpg
# 파일 이동 완료 : Hannah_Stockbauer_0002.jpg
# 파일 이동 완료 : Mike_Krzyzewski_0002.jpg
# 파일 이동 완료 : Zoran_Djindjic_0001.jpg
# 파일 이동 완료 : Petro_Symonenko_0001.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0037.jpg
# 파일 이동 완료 : Roger_King_0001.jpg
# 파일 이동 완료 : James_Kopp_0001.jpg
# 파일 이동 완료 : Raymond_Arthurs_0001.jpg
# 파일 이동 완료 : Hugh_Grant_0004.jpg
# 파일 이동 완료 : Grace_Dodd_0001.jpg
# 파일 이동 완료 : Michael_Schumacher_0011.jpg
# 파일 이동 완료 : Michael_Chang_0003.jpg
# 파일 이동 완료 : Wayne_Allard_0001.jpg
# 파일 이동 완료 : Alexandre_Herchcovitch_0001.jpg
# 파일 이동 완료 : Michael_Leavitt_0001.jpg
# 파일 이동 완료 : Chris_Neil_0001.jpg
# 파일 이동 완료 : Tippi_Hedren_0002.jpg
# 파일 이동 완료 : Emma_Thompson_0002.jpg
# 파일 이동 완료 : Jennifer_Capriati_0030.jpg
# 파일 이동 완료 : Jelena_Dokic_0002.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0082.jpg
# 파일 이동 완료 : James_Kelly_0009.jpg
# 파일 이동 완료 : Gary_Williams_0001.jpg
# 파일 이동 완료 : Jiang_Zemin_0010.jpg
# 파일 이동 완료 : Colin_Powell_0108.jpg
# 파일 이동 완료 : Lili_Marinho_0001.jpg
# 파일 이동 완료 : Jose_Maria_Aznar_0005.jpg
# 파일 이동 완료 : Goldie_Hawn_0006.jpg
# 파일 이동 완료 : Hugo_Chavez_0055.jpg
# 파일 이동 완료 : Luiz_Inacio_Lula_da_Silva_0046.jpg
# 파일 이동 완료 : Sandy_Wise_0001.jpg
# 파일 이동 완료 : David_Hyde_Pierce_0004.jpg
# 파일 이동 완료 : George_Harrison_0001.jpg
# 파일 이동 완료 : JK_Rowling_0006.jpg
# 파일 이동 완료 : Pete_Sampras_0003.jpg
# 파일 이동 완료 : Venus_Williams_0004.jpg
# 파일 이동 완료 : Heinrich_Wolfgang_0001.jpg
# 파일 이동 완료 : Galen_Rowell_0001.jpg
# 파일 이동 완료 : Benjamin_Franklin_0001.jpg
# 파일 이동 완료 : Marissa_Jaret_Winokur_0001.jpg
# 파일 이동 완료 : Carlos_Menem_0007.jpg
# 파일 이동 완료 : Kay_Bailey_Hutchison_0001.jpg
# 파일 이동 완료 : Oscar_De_La_Hoya_0004.jpg
# 파일 이동 완료 : Nancy_Reagan_0002.jpg
# 파일 이동 완료 : Jim_OBrien_0003.jpg
# 파일 이동 완료 : Guillermo_Ruiz_Polanco_0001.jpg
# 파일 이동 완료 : Catriona_Le_May_Doan_0001.jpg
# 파일 이동 완료 : Michelle_Chiklis_0001.jpg
# 파일 이동 완료 : Roger_Corbett_0001.jpg
# 파일 이동 완료 : Michael_Bloomberg_0002.jpg
# 파일 이동 완료 : Mohammad_Khatami_0003.jpg
# 파일 이동 완료 : James_Hakett_0001.jpg
# 파일 이동 완료 : Hana_Makhmalbaf_0001.jpg
# 파일 이동 완료 : Mike_Martz_0004.jpg
# 파일 이동 완료 : Mahmoud_Abbas_0010.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0023.jpg
# 파일 이동 완료 : Trent_Lott_0009.jpg
# 파일 이동 완료 : Hans_Blix_0019.jpg
# 파일 이동 완료 : Carlos_Paternina_0001.jpg
# 파일 이동 완료 : Yoriko_Kawaguchi_0010.jpg
# 파일 이동 완료 : Naomi_Watts_0018.jpg
# 파일 이동 완료 : Adrien_Brody_0002.jpg
# 파일 이동 완료 : George_W_Bush_0310.jpg
# 파일 이동 완료 : Bill_Paxton_0001.jpg
# 파일 이동 완료 : Michael_Chang_0001.jpg
# 파일 이동 완료 : Denzel_Washington_0002.jpg
# 파일 이동 완료 : Colin_Powell_0229.jpg
# 파일 이동 완료 : Sheila_Taormina_0001.jpg
# 파일 이동 완료 : Juergen_Peters_0001.jpg
# 파일 이동 완료 : Regina_Ip_0001.jpg
# 파일 이동 완료 : Lorraine_Fenton_0001.jpg
# 파일 이동 완료 : Vanessa_Redgrave_0001.jpg
# 파일 이동 완료 : Robert_Redford_0001.jpg
# 파일 이동 완료 : Brenda_Magana_0001.jpg
# 파일 이동 완료 : Dominique_de_Villepin_0008.jpg
# 파일 이동 완료 : Gray_Davis_0002.jpg
# 파일 이동 완료 : Kim_Clijsters_0011.jpg
# 파일 이동 완료 : Paris_Hilton_0001.jpg
# 파일 이동 완료 : Ariel_Sharon_0016.jpg
# 파일 이동 완료 : Sarah_Michelle_Gellar_0001.jpg
# 파일 이동 완료 : Matt_Doherty_0002.jpg
# 파일 이동 완료 : Charles_Kartman_0002.jpg
# 파일 이동 완료 : Marco_Pantani_0001.jpg
# 파일 이동 완료 : Ariel_Sharon_0008.jpg
# 파일 이동 완료 : Juan_Carlos_Ferrero_0020.jpg
# 파일 이동 완료 : David_Canary_0001.jpg
# 파일 이동 완료 : Rosalie_Perkov_0001.jpg
# 파일 이동 완료 : Hal_McCoy_0001.jpg
# 파일 이동 완료 : Bill_Simon_0006.jpg
# 파일 이동 완료 : Mary-Kate_Olsen_0002.jpg
# 파일 이동 완료 : Bill_Gates_0001.jpg
# 파일 이동 완료 : Carlos_Moya_0013.jpg
# 파일 이동 완료 : Brian_Meadors_0001.jpg
# 파일 이동 완료 : Herb_Brooks_0001.jpg
# 파일 이동 완료 : Bryan_Cooley_0001.jpg
# 파일 이동 완료 : Jacqueline_Marris_0001.jpg
# 파일 이동 완료 : Michael_Powell_0001.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0008.jpg
# 파일 이동 완료 : Al_Sharpton_0002.jpg
# 파일 이동 완료 : Mariah_Carey_0001.jpg
# 파일 이동 완료 : Sam_Gerald_0001.jpg
# 파일 이동 완료 : Christine_Gregoire_0003.jpg
# 파일 이동 완료 : James_Sensenbrenner_0001.jpg
# 파일 이동 완료 : Franz_Muentefering_0002.jpg
# 파일 이동 완료 : Dorothy_Lamour_0001.jpg
# 파일 이동 완료 : Colin_Powell_0126.jpg
# 파일 이동 완료 : Halle_Berry_0005.jpg
# 파일 이동 완료 : Gregory_Peck_0001.jpg
# 파일 이동 완료 : Kaye_Young_0001.jpg
# 파일 이동 완료 : Jean_Chretien_0051.jpg
# 파일 이동 완료 : Wen_Jiabao_0003.jpg
# 파일 이동 완료 : James_Wolfensohn_0002.jpg
# 파일 이동 완료 : Guillermo_Coria_0022.jpg
# 파일 이동 완료 : Thomas_Cloyd_0001.jpg
# 파일 이동 완료 : Hipolito_Mejia_0003.jpg
# 파일 이동 완료 : Joschka_Fischer_0016.jpg
# 파일 이동 완료 : Leslie_Ann_Woodward_0001.jpg
# 파일 이동 완료 : Kim_Gandy_0001.jpg
# 파일 이동 완료 : Ibrahim_Jaafari_0002.jpg
# 파일 이동 완료 : Richard_Harris_0001.jpg
# 파일 이동 완료 : Ludivine_Sagnier_0001.jpg
# 파일 이동 완료 : Brett_Hull_0001.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0053.jpg
# 파일 이동 완료 : Terry_McAuliffe_0001.jpg
# 파일 이동 완료 : Jakob_Kellenberger_0001.jpg
# 파일 이동 완료 : Fernando_Gonzalez_0003.jpg
# 파일 이동 완료 : Jerry_Regier_0002.jpg
# 파일 이동 완료 : John_Ashcroft_0021.jpg
# 파일 이동 완료 : Abdullah_Gul_0012.jpg
# 파일 이동 완료 : Svetlana_Koroleva_0002.jpg
# 파일 이동 완료 : Luis_Gonzalez_0001.jpg
# 파일 이동 완료 : Catherine_Zeta-Jones_0001.jpg
# 파일 이동 완료 : Dominique_de_Villepin_0002.jpg
# 파일 이동 완료 : Bashar_Assad_0004.jpg
# 파일 이동 완료 : Michael_Shelby_0001.jpg
# 파일 이동 완료 : Jan_Bjoerklund_0001.jpg
# 파일 이동 완료 : Muhammad_Ali_0005.jpg
# 파일 이동 완료 : Adolfo_Rodriguez_Saa_0002.jpg
# 파일 이동 완료 : Kim_Yong-il_0003.jpg
# 파일 이동 완료 : Valentino_Rossi_0006.jpg
# 파일 이동 완료 : Rafiq_Hariri_0001.jpg
# 파일 이동 완료 : Megawati_Sukarnoputri_0016.jpg
# 파일 이동 완료 : Carlos_Vives_0004.jpg
# 파일 이동 완료 : Julia_Ormond_0001.jpg
# 파일 이동 완료 : Frank_Van_Ecke_0001.jpg
# 파일 이동 완료 : George_W_Bush_0316.jpg
# 파일 이동 완료 : Jennifer_Capriati_0005.jpg
# 파일 이동 완료 : Guillermo_Coria_0021.jpg
# 파일 이동 완료 : Jim_Kelly_0001.jpg
# 파일 이동 완료 : David_Tornberg_0001.jpg
# 파일 이동 완료 : Lino_Oviedo_0002.jpg
# 파일 이동 완료 : John_Wolf_0001.jpg
# 파일 이동 완료 : Colin_Powell_0199.jpg
# 파일 이동 완료 : Didier_Defago_0001.jpg
# 파일 이동 완료 : John_Malkovich_0001.jpg
# 파일 이동 완료 : Joseph_Estrada_0003.jpg
# 파일 이동 완료 : Colin_Cowie_0001.jpg
# 파일 이동 완료 : Hideki_Matsui_0001.jpg
# 파일 이동 완료 : Naji_Sabri_0004.jpg
# 파일 이동 완료 : Roberto_Robaina_0001.jpg
# 파일 이동 완료 : Laura_Bush_0008.jpg
# 파일 이동 완료 : Maria_Garcia_0001.jpg
# 파일 이동 완료 : Michael_Bloomberg_0013.jpg
# 파일 이동 완료 : Cole_Chapman_0001.jpg
# 파일 이동 완료 : Yang_Jianli_0001.jpg
# 파일 이동 완료 : Ari_Fleischer_0008.jpg
# 파일 이동 완료 : John_Edwards_0005.jpg
# 파일 이동 완료 : Jeanette_Stauffer_0001.jpg
# 파일 이동 완료 : Justine_Henin_0001.jpg
# 파일 이동 완료 : Kofi_Annan_0011.jpg
# 파일 이동 완료 : Lisa_Stansfield_0001.jpg
# 파일 이동 완료 : Jim_Edmonds_0002.jpg
# 파일 이동 완료 : Joaquin_Sanchez_0001.jpg
# 파일 이동 완료 : Jeong_Se-hyun_0001.jpg
# 파일 이동 완료 : Fred_Thompson_0001.jpg
# 파일 이동 완료 : Condoleezza_Rice_0001.jpg
# 파일 이동 완료 : Miranda_Otto_0001.jpg
# 파일 이동 완료 : David_McCullough_0001.jpg
# 파일 이동 완료 : Alexander_Losyukov_0004.jpg
# 파일 이동 완료 : Rainer_Schuettler_0005.jpg
# 파일 이동 완료 : Kim_Dae-jung_0003.jpg
# 파일 이동 완료 : Roger_Federer_0013.jpg
# 파일 이동 완료 : John_Taylor_0001.jpg
# 파일 이동 완료 : Jose_Theodore_0002.jpg
# 파일 이동 완료 : Sergey_Lavrov_0009.jpg
# 파일 이동 완료 : John_Hartson_0001.jpg
# 파일 이동 완료 : Michael_Bloomberg_0005.jpg
# 파일 이동 완료 : John_Ashcroft_0007.jpg
# 파일 이동 완료 : Kjell_Magne_Bondevik_0003.jpg
# 파일 이동 완료 : David_Montoya_0001.jpg
# 파일 이동 완료 : Bill_Simon_0003.jpg
# 파일 이동 완료 : Mahathir_Mohamad_0011.jpg
# 파일 이동 완료 : Ahmed_Chalabi_0005.jpg
# 파일 이동 완료 : Keanu_Reeves_0009.jpg
# 파일 이동 완료 : Thomas_Day_0001.jpg
# 파일 이동 완료 : Colin_Powell_0002.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0033.jpg
# 파일 이동 완료 : Vladimir_Putin_0027.jpg
# 파일 이동 완료 : Kelvin_Sampson_0003.jpg
# 파일 이동 완료 : Paul_Desmarais_0001.jpg
# 파일 이동 완료 : Hal_Gehman_0004.jpg
# 파일 이동 완료 : Colin_Powell_0059.jpg
# 파일 이동 완료 : Jose_Serra_0003.jpg
# 파일 이동 완료 : Jim_Hahn_0002.jpg
# 파일 이동 완료 : Hamzah_Haz_0002.jpg
# 파일 이동 완료 : Robert_Blake_0001.jpg
# 파일 이동 완료 : Munir_Akram_0001.jpg
# 파일 이동 완료 : Mekhi_Phifer_0001.jpg
# 파일 이동 완료 : Sam_Bith_0002.jpg
# 파일 이동 완료 : Jeong_Se-hyun_0006.jpg
# 파일 이동 완료 : Adam_Scott_0001.jpg
# 파일 이동 완료 : Anthony_Pisciotti_0001.jpg
# 파일 이동 완료 : Uzi_Landau_0001.jpg
# 파일 이동 완료 : Mahmoud_Abbas_0022.jpg
# 파일 이동 완료 : Juan_Carlos_Ferrero_0001.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0024.jpg
# 파일 이동 완료 : Arnold_Schwarzenegger_0016.jpg
# 파일 이동 완료 : Anthony_Corso_0001.jpg
# 파일 이동 완료 : Martin_Scorsese_0007.jpg
# 파일 이동 완료 : Mitchell_Daniels_0004.jpg
# 파일 이동 완료 : Tom_Watson_0003.jpg
# 파일 이동 완료 : Tori_Amos_0001.jpg
# 파일 이동 완료 : Paul_Johnson_0001.jpg
# 파일 이동 완료 : Recep_Tayyip_Erdogan_0021.jpg
# 파일 이동 완료 : Atal_Bihari_Vajpayee_0012.jpg
# 파일 이동 완료 : Susan_Sarandon_0002.jpg
# 파일 이동 완료 : Hans_Blix_0027.jpg
# 파일 이동 완료 : Andrew_Gilligan_0001.jpg
# 파일 이동 완료 : Mohammed_Dahlan_0001.jpg
# 파일 이동 완료 : Tim_Duncan_0002.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0091.jpg
# 파일 이동 완료 : Mike_Myers_0005.jpg
# 파일 이동 완료 : Tim_Henman_0004.jpg
# 파일 이동 완료 : Makhdoom_Amin_Fahim_0003.jpg
# 파일 이동 완료 : Keith_Fotta_0001.jpg
# 파일 이동 완료 : Mark_Hurlbert_0001.jpg
# 파일 이동 완료 : Tony_Blair_0083.jpg
# 파일 이동 완료 : Nanni_Moretti_0001.jpg
# 파일 이동 완료 : Andrea_Yates_0001.jpg
# 파일 이동 완료 : Tony_Blair_0036.jpg
# 파일 이동 완료 : Arnold_Palmer_0002.jpg
# 파일 이동 완료 : Charles_Bronson_0002.jpg
# 파일 이동 완료 : Jim_Carrey_0002.jpg
# 파일 이동 완료 : Steven_Tyler_0001.jpg
# 파일 이동 완료 : Kurt_Tanabe_0001.jpg
# 파일 이동 완료 : Anne_Krueger_0003.jpg
# 파일 이동 완료 : Pierre_Png_0001.jpg
# 파일 이동 완료 : Carla_Del_Ponte_0001.jpg
# 파일 이동 완료 : Gordon_Brown_0011.jpg
# 파일 이동 완료 : Jong_Wook_Lee_0003.jpg
# 파일 이동 완료 : John_Elway_0001.jpg
# 파일 이동 완료 : Steve_McManaman_0001.jpg
# 파일 이동 완료 : Gray_Davis_0016.jpg
# 파일 이동 완료 : Anthony_Rackauckas_0001.jpg
# 파일 이동 완료 : Michael_Brandon_0001.jpg
# 파일 이동 완료 : Bill_Frist_0003.jpg
# 파일 이동 완료 : William_Delahunt_0001.jpg
# 파일 이동 완료 : Debbie_Allen_0001.jpg
# 파일 이동 완료 : Steve_Coterill_0001.jpg
# 파일 이동 완료 : John_Banko_0002.jpg
# 파일 이동 완료 : Recep_Tayyip_Erdogan_0014.jpg
# 파일 이동 완료 : Lyle_Vanclief_0002.jpg
# 파일 이동 완료 : Hugo_Chavez_0028.jpg
# 파일 이동 완료 : Joe_Gatti_0001.jpg
# 파일 이동 완료 : Angie_Martinez_0001.jpg
# 파일 이동 완료 : George_W_Bush_0206.jpg
# 파일 이동 완료 : Shimon_Peres_0002.jpg
# 파일 이동 완료 : Michelle_Pfeiffer_0001.jpg
# 파일 이동 완료 : Jerry_Springer_0002.jpg
# 파일 이동 완료 : Jean_Carnahan_0002.jpg
# 파일 이동 완료 : Mahathir_Mohamad_0007.jpg
# 파일 이동 완료 : John_Danforth_0001.jpg
# 파일 이동 완료 : Kamal_Kharrazi_0006.jpg
# 파일 이동 완료 : Herb_Dhaliwal_0001.jpg
# 파일 이동 완료 : Jong_Wook_Lee_0001.jpg
# 파일 이동 완료 : Laura_Flessel_0001.jpg
# 파일 이동 완료 : Alex_Holmes_0001.jpg
# 파일 이동 완료 : Jay_Rasulo_0002.jpg
# 파일 이동 완료 : Robert_Duvall_0008.jpg
# 파일 이동 완료 : Evan_Rachel_Wood_0003.jpg
# 파일 이동 완료 : Billy_Sollie_0001.jpg
# 파일 이동 완료 : Jean_Chretien_0012.jpg
# 파일 이동 완료 : Tommy_Thompson_0005.jpg
# 파일 이동 완료 : Donald_Carty_0001.jpg
# 파일 이동 완료 : Colin_Powell_0159.jpg
# 파일 이동 완료 : Andre_Agassi_0030.jpg
# 파일 이동 완료 : Steve_Nash_0004.jpg
# 파일 이동 완료 : Laurent_Gbagbo_0002.jpg
# 파일 이동 완료 : Kathy_Gannon_0001.jpg
# 파일 이동 완료 : Vicente_Fox_0002.jpg
# 파일 이동 완료 : Brendan_Gaughan_0001.jpg
# 파일 이동 완료 : Jacques_Rogge_0005.jpg
# 파일 이동 완료 : Jean_Brumley_0001.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0058.jpg
# 파일 이동 완료 : John_Negroponte_0002.jpg
# 파일 이동 완료 : Jackie_Chan_0004.jpg
# 파일 이동 완료 : Gloria_Macapagal_Arroyo_0017.jpg
# 파일 이동 완료 : Robert_De_Niro_0001.jpg
# 파일 이동 완료 : Marco_Irizarry_0001.jpg
# 파일 이동 완료 : Colin_Powell_0149.jpg
# 파일 이동 완료 : Emma_Watson_0003.jpg
# 파일 이동 완료 : John_Kerry_0008.jpg
# 파일 이동 완료 : Nicole_Kidman_0017.jpg
# 파일 이동 완료 : Garry_McCoy_0001.jpg
# 파일 이동 완료 : Martin_Bandier_0001.jpg
# 파일 이동 완료 : Stan_Kroenke_0001.jpg
# 파일 이동 완료 : Jerry_McEntee_0001.jpg
# 파일 이동 완료 : Juan_Carlos_Ferrero_0025.jpg
# 파일 이동 완료 : Larry_Thompson_0001.jpg
# 파일 이동 완료 : Joe_Torre_0003.jpg
# 파일 이동 완료 : Xiang_Liu_0001.jpg
# 파일 이동 완료 : Nicanor_Duarte_Frutos_0011.jpg
# 파일 이동 완료 : Saddam_Hussein_0005.jpg
# 파일 이동 완료 : Vince_Carter_0003.jpg
# 파일 이동 완료 : Herb_Sendek_0002.jpg
# 파일 이동 완료 : Gene_Robinson_0005.jpg
# 파일 이동 완료 : Vaclav_Havel_0003.jpg
# 파일 이동 완료 : Noelle_Bush_0003.jpg
# 파일 이동 완료 : Laila_Ali_0001.jpg
# 파일 이동 완료 : Christopher_Reeve_0004.jpg
# 파일 이동 완료 : Ari_Fleischer_0003.jpg
# 파일 이동 완료 : Leon_Lai_0001.jpg
# 파일 이동 완료 : Susan_Whelan_0001.jpg
# 파일 이동 완료 : Leon_Barmore_0001.jpg
# 파일 이동 완료 : Mohammed_Al-Douri_0012.jpg
# 파일 이동 완료 : Mike_Thibault_0001.jpg
# 파일 이동 완료 : Nestor_Kirchner_0014.jpg
# 파일 이동 완료 : Bill_Graham_0007.jpg
# 파일 이동 완료 : Hisashi_Owada_0001.jpg
# 파일 이동 완료 : Kristanna_Loken_0004.jpg
# 파일 이동 완료 : Bill_Graham_0006.jpg
# 파일 이동 완료 : Steve_Park_0001.jpg
# 파일 이동 완료 : Philippe_Noiret_0001.jpg
# 파일 이동 완료 : Paradorn_Srichaphan_0005.jpg
# 파일 이동 완료 : Mike_Weir_0006.jpg
# 파일 이동 완료 : Angelina_Jolie_0016.jpg
# 파일 이동 완료 : Atom_Egoyan_0001.jpg
# 파일 이동 완료 : Wu_Yi_0003.jpg
# 파일 이동 완료 : Juan_Carlos_Ferrero_0015.jpg
# 파일 이동 완료 : Terry_Stotts_0001.jpg
# 파일 이동 완료 : Thomas_OBrien_0005.jpg
# 파일 이동 완료 : Benjamin_Netanyahu_0002.jpg
# 파일 이동 완료 : George_W_Bush_0026.jpg
# 파일 이동 완료 : Kim_Clijsters_0010.jpg
# 파일 이동 완료 : Claudia_Pechstein_0003.jpg
# 파일 이동 완료 : Paul_Lockhart_0001.jpg
# 파일 이동 완료 : Yu_Shyi-kun_0002.jpg
# 파일 이동 완료 : Rita_Wilson_0003.jpg
# 파일 이동 완료 : Frederique_van_der_Wal_0001.jpg
# 파일 이동 완료 : George_W_Bush_0014.jpg
# 파일 이동 완료 : Jesse_Ventura_0003.jpg
# 파일 이동 완료 : George_W_Bush_0318.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0016.jpg
# 파일 이동 완료 : Guillermo_Coria_0001.jpg
# 파일 이동 완료 : Anthony_Pico_0001.jpg
# 파일 이동 완료 : Tiger_Woods_0009.jpg
# 파일 이동 완료 : Michael_Caine_0004.jpg
# 파일 이동 완료 : Helene_Eksterowicz_0001.jpg
# 파일 이동 완료 : Lauren_Killian_0001.jpg
# 파일 이동 완료 : David_Caruso_0001.jpg
# 파일 이동 완료 : Gloria_Macapagal_Arroyo_0004.jpg
# 파일 이동 완료 : Bertie_Ahern_0001.jpg
# 파일 이동 완료 : Suk_Chung_Hong_0001.jpg
# 파일 이동 완료 : Gloria_Macapagal_Arroyo_0037.jpg
# 파일 이동 완료 : Ahmed_Chalabi_0002.jpg
# 파일 이동 완료 : Arnold_Schwarzenegger_0018.jpg
# 파일 이동 완료 : Carlos_Moya_0005.jpg
# 파일 이동 완료 : Darren_Campel_0001.jpg
# 파일 이동 완료 : Ashanti_0005.jpg
# 파일 이동 완료 : Will_Self_0001.jpg
# 파일 이동 완료 : Hu_Jintao_0001.jpg
# 파일 이동 완료 : Joseph_Lopez_0001.jpg
# 파일 이동 완료 : Johan_Bruyneel_0001.jpg
# 파일 이동 완료 : Valdas_Adamkus_0001.jpg
# 파일 이동 완료 : Qusai_Hussein_0001.jpg
# 파일 이동 완료 : Jason_Keep_0001.jpg
# 파일 이동 완료 : Rudolph_Giuliani_0014.jpg
# 파일 이동 완료 : Jason_Biggs_0001.jpg
# 파일 이동 완료 : Laurence_Fishburne_0001.jpg
# 파일 이동 완료 : Chang_Dae-whan_0001.jpg
# 파일 이동 완료 : Stephen_Swindal_0001.jpg
# 파일 이동 완료 : Vanessa_Redgrave_0005.jpg
# 파일 이동 완료 : Robert_DeFraites_0001.jpg
# 파일 이동 완료 : George_W_Bush_0504.jpg
# 파일 이동 완료 : Vicente_Fox_0027.jpg
# 파일 이동 완료 : Thomas_OBrien_0004.jpg
# 파일 이동 완료 : Wen_Jiabao_0013.jpg
# 파일 이동 완료 : Alfredo_Pena_0001.jpg
# 파일 이동 완료 : Osama_bin_Laden_0004.jpg
# 파일 이동 완료 : Oswald_Gruebel_0001.jpg
# 파일 이동 완료 : Joschka_Fischer_0009.jpg
# 파일 이동 완료 : Kimora_Lee_0001.jpg
# 파일 이동 완료 : Thomas_Mesereau_Jr_0001.jpg
# 파일 이동 완료 : Noah_Wyle_0001.jpg
# 파일 이동 완료 : David_Chase_0001.jpg
# 파일 이동 완료 : Des_Brown_0001.jpg
# 파일 이동 완료 : Justine_Henin_0002.jpg
# 파일 이동 완료 : Megawati_Sukarnoputri_0026.jpg
# 파일 이동 완료 : Hans_Blix_0007.jpg
# 파일 이동 완료 : Sheikh_Ahmed_Yassin_0001.jpg
# 파일 이동 완료 : Thomas_Fargo_0001.jpg
# 파일 이동 완료 : John_Henry_0001.jpg
# 파일 이동 완료 : Rick_Santorum_0001.jpg
# 파일 이동 완료 : Leon_LaPorte_0001.jpg
# 파일 이동 완료 : Mohammed_Al_Hindi_0001.jpg
# 파일 이동 완료 : Margaret_Okayo_0001.jpg
# 파일 이동 완료 : Lisa_Marie_Presley_0002.jpg
# 파일 이동 완료 : Holly_Hunter_0001.jpg
# 파일 이동 완료 : Ray_Sherman_0001.jpg
# 파일 이동 완료 : Malcolm_Jamal_Warner_0001.jpg
# 파일 이동 완료 : George_W_Bush_0456.jpg
# 파일 이동 완료 : Roger_Lyons_0001.jpg
# 파일 이동 완료 : Tony_Blair_0100.jpg
# 파일 이동 완료 : Charles_Taylor_0001.jpg
# 파일 이동 완료 : Jeb_Bush_0002.jpg
# 파일 이동 완료 : Milt_Palacio_0001.jpg
# 파일 이동 완료 : Marian_Dolan_0001.jpg
# 파일 이동 완료 : Jennifer_Aniston_0001.jpg
# 파일 이동 완료 : Suzanne_Mubarak_0001.jpg
# 파일 이동 완료 : Mike_Myers_0001.jpg
# 파일 이동 완료 : Tina_Fey_0001.jpg
# 파일 이동 완료 : Hugo_Chavez_0043.jpg
# 파일 이동 완료 : Dorothy_Loudon_0001.jpg
# 파일 이동 완료 : Patsy_Mink_0001.jpg
# 파일 이동 완료 : Binyamin_Ben-Eliezer_0006.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0017.jpg
# 파일 이동 완료 : John_Snow_0014.jpg
# 파일 이동 완료 : Christian_Fittipaldi_0001.jpg
# 파일 이동 완료 : Rick_Perry_0001.jpg
# 파일 이동 완료 : Shanna_Zolman_0001.jpg
# 파일 이동 완료 : Ilan_Ramon_0001.jpg
# 파일 이동 완료 : Sargis_Sargsian_0001.jpg
# 파일 이동 완료 : George_W_Bush_0390.jpg
# 파일 이동 완료 : Paul_Tagliabue_0001.jpg
# 파일 이동 완료 : Norm_Coleman_0004.jpg
# 파일 이동 완료 : Rupert_Grint_0003.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0011.jpg
# 파일 이동 완료 : Cari_Davis_0001.jpg
# 파일 이동 완료 : Vladimir_Putin_0017.jpg
# 파일 이동 완료 : George_W_Bush_0255.jpg
# 파일 이동 완료 : Gustavo_Kuerten_0001.jpg
# 파일 이동 완료 : Vicente_Fox_0017.jpg
# 파일 이동 완료 : Vincent_Gallo_0003.jpg
# 파일 이동 완료 : David_Trimble_0002.jpg
# 파일 이동 완료 : Howard_Dean_0001.jpg
# 파일 이동 완료 : Josh_Kronfeld_0001.jpg
# 파일 이동 완료 : Mary_Frances_Seiter_0001.jpg
# 파일 이동 완료 : Prince_Harry_0002.jpg
# 파일 이동 완료 : Ricardo_Lagos_0021.jpg
# 파일 이동 완료 : Robert_Mueller_0004.jpg
# 파일 이동 완료 : Darryl_McDaniels_0001.jpg
# 파일 이동 완료 : Aleksander_Kwasniewski_0003.jpg
# 파일 이동 완료 : John_Paul_DeJoria_0001.jpg
# 파일 이동 완료 : Mike_Martz_0002.jpg
# 파일 이동 완료 : Franklin_Damann_0001.jpg
# 파일 이동 완료 : Melvin_Talbert_0001.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0092.jpg
# 파일 이동 완료 : Jade_Jagger_0001.jpg
# 파일 이동 완료 : Marina_Anissina_0001.jpg
# 파일 이동 완료 : Jean_Chretien_0001.jpg
# 파일 이동 완료 : Bruce_Springsteen_0004.jpg
# 파일 이동 완료 : Don_Carcieri_0001.jpg
# 파일 이동 완료 : Tim_Norbeck_0001.jpg
# 파일 이동 완료 : Michael_Jordan_0001.jpg
# 파일 이동 완료 : John_McCallum_0001.jpg
# 파일 이동 완료 : Lance_Armstrong_0005.jpg
# 파일 이동 완료 : Angelo_Reyes_0003.jpg
# 파일 이동 완료 : Eduard_Shevardnadze_0004.jpg
# 파일 이동 완료 : Joschka_Fischer_0006.jpg
# 파일 이동 완료 : Lance_Armstrong_0007.jpg
# 파일 이동 완료 : Khin_Nyunt_0001.jpg
# 파일 이동 완료 : Igor_Ivanov_0011.jpg
# 파일 이동 완료 : Rohinton_Mistry_0001.jpg
# 파일 이동 완료 : Jim_Ahern_0001.jpg
# 파일 이동 완료 : William_Macy_0005.jpg
# 파일 이동 완료 : George_Foreman_0001.jpg
# 파일 이동 완료 : Hal_Gehman_0003.jpg
# 파일 이동 완료 : Clint_Eastwood_0001.jpg
# 파일 이동 완료 : David_Nalbandian_0012.jpg
# 파일 이동 완료 : Branko_Crvenkovski_0002.jpg
# 파일 이동 완료 : Tony_Blair_0075.jpg
# 파일 이동 완료 : Gloria_Macapagal_Arroyo_0031.jpg
# 파일 이동 완료 : Dave_McNealey_0001.jpg
# 파일 이동 완료 : Saddam_Hussein_0007.jpg
# 파일 이동 완료 : Linda_Lingle_0001.jpg
# 파일 이동 완료 : Ridley_Scott_0001.jpg
# 파일 이동 완료 : John_Baldacci_0001.jpg
# 파일 이동 완료 : George_W_Bush_0244.jpg
# 파일 이동 완료 : Jessica_Lynch_0002.jpg
# 파일 이동 완료 : Sophia_Loren_0002.jpg
# 파일 이동 완료 : Ion_Tiriac_0001.jpg
# 파일 이동 완료 : Kate_Richardson_0001.jpg
# 파일 이동 완료 : Jennifer_Aniston_0006.jpg
# 파일 이동 완료 : Martin_Cauchon_0001.jpg
# 파일 이동 완료 : George_W_Bush_0170.jpg
# 파일 이동 완료 : Martin_ONeill_0001.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0012.jpg
# 파일 이동 완료 : Tamara_Stokes_0001.jpg
# 파일 이동 완료 : George_W_Bush_0399.jpg
# 파일 이동 완료 : Steve_Kerr_0001.jpg
# 파일 이동 완료 : Robert_Evans_0002.jpg
# 파일 이동 완료 : Laura_Bush_0005.jpg
# 파일 이동 완료 : Ray_Romano_0001.jpg
# 파일 이동 완료 : Igor_Ivanov_0007.jpg
# 파일 이동 완료 : Vicente_Fox_0029.jpg
# 파일 이동 완료 : Vanessa_Incontrada_0001.jpg
# 파일 이동 완료 : Andrew_Wetzler_0001.jpg
# 파일 이동 완료 : Luiz_Inacio_Lula_da_Silva_0010.jpg
# 파일 이동 완료 : Jose_Serra_0006.jpg
# 파일 이동 완료 : Mahmoud_Abbas_0001.jpg
# 파일 이동 완료 : Stacey_Yamaguchi_0001.jpg
# 파일 이동 완료 : John_Bolton_0001.jpg
# 파일 이동 완료 : David_Caraway_0001.jpg
# 파일 이동 완료 : Julie_Gerberding_0011.jpg
# 파일 이동 완료 : George_Clooney_0004.jpg
# 파일 이동 완료 : Serena_Williams_0013.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0019.jpg
# 파일 이동 완료 : Alexandra_Stevenson_0003.jpg
# 파일 이동 완료 : Randall_Tobias_0001.jpg
# 파일 이동 완료 : Joe_Nichols_0003.jpg
# 파일 이동 완료 : Alejandro_Gonzalez_Inarritu_0001.jpg
# 파일 이동 완료 : Anthony_Garotinho_0001.jpg
# 파일 이동 완료 : Doug_Wilson_0001.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0014.jpg
# 파일 이동 완료 : Marat_Safin_0003.jpg
# 파일 이동 완료 : David_Myers_0002.jpg
# 파일 이동 완료 : Al_Gore_0008.jpg
# 파일 이동 완료 : Colin_Powell_0166.jpg
# 파일 이동 완료 : Vince_Gill_0002.jpg
# 파일 이동 완료 : Lindsay_Davenport_0007.jpg
# 파일 이동 완료 : Paul_Pierce_0001.jpg
# 파일 이동 완료 : George_W_Bush_0184.jpg
# 파일 이동 완료 : Martina_Hingis_0003.jpg
# 파일 이동 완료 : Asif_Hanif_0001.jpg
# 파일 이동 완료 : Dunn_Lampton_0001.jpg
# 파일 이동 완료 : Michael_Winterbottom_0001.jpg
# 파일 이동 완료 : Jennifer_Garner_0005.jpg
# 파일 이동 완료 : James_Cunningham_0003.jpg
# 파일 이동 완료 : Vadim_Devyatovskiy_0001.jpg
# 파일 이동 완료 : Recep_Tayyip_Erdogan_0019.jpg
# 파일 이동 완료 : Natalya_Sazanovich_0001.jpg
# 파일 이동 완료 : Sergei_Ivanov_0003.jpg
# 파일 이동 완료 : Janet_Chandler_0001.jpg
# 파일 이동 완료 : Barbra_Streisand_0003.jpg
# 파일 이동 완료 : Paul_Bremer_0002.jpg
# 파일 이동 완료 : Bob_Sulkin_0001.jpg
# 파일 이동 완료 : Keith_Lockhart_0001.jpg
# 파일 이동 완료 : Vojislav_Kostunica_0005.jpg
# 파일 이동 완료 : Ann_Veneman_0009.jpg
# 파일 이동 완료 : Michael_Bloomberg_0004.jpg
# 파일 이동 완료 : Minnie_Mendoza_0001.jpg
# 파일 이동 완료 : Lance_Armstrong_0017.jpg
# 파일 이동 완료 : George_W_Bush_0516.jpg
# 파일 이동 완료 : Prince_Rainier_III_0001.jpg
# 파일 이동 완료 : George_W_Bush_0028.jpg
# 파일 이동 완료 : Colin_Prescot_0001.jpg
# 파일 이동 완료 : Lance_Armstrong_0014.jpg
# 파일 이동 완료 : Michel_Temer_0001.jpg
# 파일 이동 완료 : Bill_Guerin_0001.jpg
# 파일 이동 완료 : Jan_Ullrich_0003.jpg
# 파일 이동 완료 : Leonid_Kuchma_0004.jpg
# 파일 이동 완료 : Prince_Edward_0002.jpg
# 파일 이동 완료 : Chris_Reitsma_0001.jpg
# 파일 이동 완료 : Edward_Johnson_0001.jpg
# 파일 이동 완료 : Martha_Bowen_0002.jpg
# 파일 이동 완료 : Dan_Wheldon_0002.jpg
# 파일 이동 완료 : Saddam_Hussein_0018.jpg
# 파일 이동 완료 : Carlos_Ortega_0002.jpg
# 파일 이동 완료 : Calvin_Harrison_0001.jpg
# 파일 이동 완료 : John_Bolton_0012.jpg
# 파일 이동 완료 : Jean-Patrick_Nazon_0001.jpg
# 파일 이동 완료 : King_Abdullah_II_0005.jpg
# 파일 이동 완료 : Jennifer_Keller_0002.jpg
# 파일 이동 완료 : Cindy_Moll_0001.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0060.jpg
# 파일 이동 완료 : Hunter_Bates_0001.jpg
# 파일 이동 완료 : Marc_Grossman_0001.jpg
# 파일 이동 완료 : Gary_Doer_0001.jpg
# 파일 이동 완료 : Svetislav_Pesic_0001.jpg
# 파일 이동 완료 : Elva_Hsiao_0001.jpg
# 파일 이동 완료 : Lesley_McCulloch_0003.jpg
# 파일 이동 완료 : Elvis_Presley_0002.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0018.jpg
# 파일 이동 완료 : Cynthia_Rowley_0001.jpg
# 파일 이동 완료 : Gloria_Macapagal_Arroyo_0036.jpg
# 파일 이동 완료 : Mick_Jagger_0005.jpg
# 파일 이동 완료 : Gilles_Panizzi_0001.jpg
# 파일 이동 완료 : George_W_Bush_0499.jpg
# 파일 이동 완료 : Cindy_Crawford_0003.jpg
# 파일 이동 완료 : Richard_Myers_0001.jpg
# 파일 이동 완료 : Lance_Armstrong_0003.jpg
# 파일 이동 완료 : Winona_Ryder_0004.jpg
# 파일 이동 완료 : Tim_Matheson_0001.jpg
# 파일 이동 완료 : Fidel_Castro_0007.jpg
# 파일 이동 완료 : Chuck_Amato_0001.jpg
# 파일 이동 완료 : John_Travolta_0005.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0003.jpg
# 파일 이동 완료 : Winona_Ryder_0014.jpg
# 파일 이동 완료 : Theresa_May_0002.jpg
# 파일 이동 완료 : Laura_Bush_0004.jpg
# ...
# 파일 이동 완료 : Michael_Leavitt_0002.jpg
# 파일 이동 완료 : Brian_Wells_0001.jpg
# 파일 이동 완료 : John_Rosa_0003.jpg
# 파일 이동 완료 : James_Meeks_0001.jpg
# 파일 이동 완료 : Gary_Dellaverson_0001.jpg
# 파일 이동 완료 : Phoenix_Chang_0001.jpg
# 파일 이동 완료 : Hugo_Chavez_0004.jpg
# 파일 이동 완료 : Joey_Mantia_0001.jpg
# 파일 이동 완료 : Amanda_Coetzer_0001.jpg
# 파일 이동 완료 : Gloria_Macapagal_Arroyo_0027.jpg
# 파일 이동 완료 : Dianne_Feinstein_0002.jpg
# 파일 이동 완료 : Aline_Chretien_0001.jpg
# 파일 이동 완료 : Natasha_McElhone_0002.jpg
# 파일 이동 완료 : Ralf_Schumacher_0005.jpg
# 파일 이동 완료 : Abdel_Madi_Shabneh_0001.jpg
# 파일 이동 완료 : Lance_Bass_0001.jpg
# 파일 이동 완료 : Karin_Stoiber_0002.jpg
# 파일 이동 완료 : Robert_Downey_Jr_0001.jpg
# 파일 이동 완료 : Petria_Thomas_0003.jpg
# 파일 이동 완료 : Ariel_Sharon_0066.jpg
# 파일 이동 완료 : Ali_Naimi_0006.jpg
# 파일 이동 완료 : Adam_Kennedy_0001.jpg
# 파일 이동 완료 : Lee_Chang-dong_0001.jpg
# 파일 이동 완료 : John_Bolton_0009.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0053.jpg
# 파일 이동 완료 : Charles_Moose_0011.jpg
# 파일 이동 완료 : Jiang_Zemin_0015.jpg
# 파일 이동 완료 : George_W_Bush_0064.jpg
# 파일 이동 완료 : Darren_Clarke_0001.jpg
# 파일 이동 완료 : Pete_Sampras_0019.jpg
# 파일 이동 완료 : George_Robertson_0004.jpg
# 파일 이동 완료 : Nan_Wang_0002.jpg
# 파일 이동 완료 : George_W_Bush_0382.jpg
# 파일 이동 완료 : Jerelle_Kraus_0001.jpg
# 파일 이동 완료 : Julianne_Moore_0006.jpg
# 파일 이동 완료 : Mike_Weir_0004.jpg
# 파일 이동 완료 : Liu_Mingkang_0002.jpg
# 파일 이동 완료 : Todd_Wike_0001.jpg
# 파일 이동 완료 : Catherine_Zeta-Jones_0010.jpg
# 파일 이동 완료 : Horst_Koehler_0001.jpg
# 파일 이동 완료 : Dick_Clark_0003.jpg
# 파일 이동 완료 : Phillip_Fulmer_0001.jpg
# 파일 이동 완료 : Matt_Damon_0001.jpg
# 파일 이동 완료 : George_W_Bush_0199.jpg
# 파일 이동 완료 : Slobodan_Milosevic_0003.jpg
# 파일 이동 완료 : Hector_Grullon_0001.jpg
# 파일 이동 완료 : Tom_Daschle_0019.jpg
# 파일 이동 완료 : Roberto_Carlos_0003.jpg
# 파일 이동 완료 : Jim_Tressel_0001.jpg
# 파일 이동 완료 : Tommy_Haas_0003.jpg
# 파일 이동 완료 : Wayne_Gretzky_0003.jpg
# 파일 이동 완료 : Spencer_Abraham_0017.jpg
# 파일 이동 완료 : Jiang_Zemin_0020.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0003.jpg
# 파일 이동 완료 : Derek_Jeter_0002.jpg
# 파일 이동 완료 : Gunter_Pleuger_0006.jpg
# 파일 이동 완료 : Jack_Straw_0018.jpg
# 파일 이동 완료 : Hans_Blix_0015.jpg
# 파일 이동 완료 : Paul_Burrell_0011.jpg
# 파일 이동 완료 : Antonio_Banderas_0005.jpg
# 파일 이동 완료 : Asa_Hutchinson_0001.jpg
# 파일 이동 완료 : Jean-Claude_Braquet_0002.jpg
# 파일 이동 완료 : Markus_Beyer_0001.jpg
# 파일 이동 완료 : Kirk_Douglas_0001.jpg
# 파일 이동 완료 : Megawati_Sukarnoputri_0001.jpg
# 파일 이동 완료 : Keith_Urban_0001.jpg
# 파일 이동 완료 : Adam_Herbert_0001.jpg
# 파일 이동 완료 : Larry_Coker_0004.jpg
# 파일 이동 완료 : Colin_Montgomerie_0005.jpg
# 파일 이동 완료 : Jean_Chretien_0038.jpg
# 파일 이동 완료 : George_W_Bush_0217.jpg
# 파일 이동 완료 : Carlos_Salinas_0001.jpg
# 파일 이동 완료 : Fidel_Castro_0002.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0047.jpg
# 파일 이동 완료 : Gabriel_Hughes_0001.jpg
# 파일 이동 완료 : Ken_Balk_0001.jpg
# 파일 이동 완료 : Matthew_Perry_0007.jpg
# 파일 이동 완료 : Bruce_Springsteen_0001.jpg
# 파일 이동 완료 : Ascencion_Barajas_0001.jpg
# 파일 이동 완료 : Supachai_Panitchpakdi_0001.jpg
# 파일 이동 완료 : Ronaldo_Luis_Nazario_de_Lima_0002.jpg
# 파일 이동 완료 : Chris_Pronger_0001.jpg
# 파일 이동 완료 : Roger_Federer_0009.jpg
# 파일 이동 완료 : Alejandro_Toledo_0025.jpg
# 파일 이동 완료 : Paul-Henri_Mathieu_0002.jpg
# 파일 이동 완료 : Muhammad_Saeed_al-Sahhaf_0002.jpg
# 파일 이동 완료 : Naomi_Watts_0012.jpg
# 파일 이동 완료 : Ben_Affleck_0007.jpg
# 파일 이동 완료 : Colin_Powell_0036.jpg
# 파일 이동 완료 : Kofi_Annan_0010.jpg
# 파일 이동 완료 : Michael_Bloomberg_0007.jpg
# 파일 이동 완료 : Jason_Kidd_0001.jpg
# 파일 이동 완료 : Takeo_Fukui_0001.jpg
# 파일 이동 완료 : Natalie_Coughlin_0004.jpg
# 파일 이동 완료 : Meryl_Streep_0013.jpg
# 파일 이동 완료 : Ellen_DeGeneres_0002.jpg
# 파일 이동 완료 : Lesley_McCulloch_0002.jpg
# 파일 이동 완료 : Chris_Crocker_0001.jpg
# 파일 이동 완료 : Brian_De_Palma_0001.jpg
# 파일 이동 완료 : Hermann_Maier_0001.jpg
# 파일 이동 완료 : Jiri_Novak_0006.jpg
# 파일 이동 완료 : Atal_Bihari_Vajpayee_0001.jpg
# 파일 이동 완료 : David_Spade_0002.jpg
# 파일 이동 완료 : Colin_Powell_0232.jpg
# 파일 이동 완료 : Jesus_Cardenal_0001.jpg
# 파일 이동 완료 : Laura_Bush_0027.jpg
# 파일 이동 완료 : Roy_Moore_0002.jpg
# 파일 이동 완료 : Charlotte_Casiraghi_0001.jpg
# 파일 이동 완료 : Dennis_Kucinich_0007.jpg
# 파일 이동 완료 : Prince_Charles_0002.jpg
# 파일 이동 완료 : Melissa_Mulloy_0001.jpg
# 파일 이동 완료 : Albert_Costa_0006.jpg
# 파일 이동 완료 : Thierry_Falise_0003.jpg
# 파일 이동 완료 : Elijah_Wood_0002.jpg
# 파일 이동 완료 : Marissa_Jaret_Winokur_0002.jpg
# 파일 이동 완료 : Matt_Herden_0001.jpg
# 파일 이동 완료 : Howard_Stern_0001.jpg
# 파일 이동 완료 : Alejandro_Atchugarry_0002.jpg
# 파일 이동 완료 : James_Hallock_0001.jpg
# 파일 이동 완료 : Muhammad_Ali_0009.jpg
# 파일 이동 완료 : Colin_Powell_0227.jpg
# 파일 이동 완료 : Kobe_Bryant_0001.jpg
# 파일 이동 완료 : Roger_Clemens_0002.jpg
# 파일 이동 완료 : Robert_Blake_0003.jpg
# 파일 이동 완료 : Chan_Gailey_0002.jpg
# 파일 이동 완료 : Mark_Richt_0002.jpg
# 파일 이동 완료 : Mike_Weir_0002.jpg
# 파일 이동 완료 : Jan_De_Bont_0001.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0008.jpg
# 파일 이동 완료 : Kathryn_Tucker_0001.jpg
# 파일 이동 완료 : Morgan_Fairchild_0001.jpg
# 파일 이동 완료 : James_Williams_0001.jpg
# 파일 이동 완료 : James_Brazelton_0001.jpg
# 파일 이동 완료 : Hermann_Maier_0002.jpg
# 파일 이동 완료 : Ricky_Barnes_0002.jpg
# 파일 이동 완료 : Thomas_Ferguson_0001.jpg
# 파일 이동 완료 : Sean_Patrick_OMalley_0003.jpg
# 파일 이동 완료 : Franz_Muentefering_0001.jpg
# 파일 이동 완료 : Joe_Nichols_0002.jpg
# 파일 이동 완료 : Boris_Becker_0003.jpg
# 파일 이동 완료 : Andre_Agassi_0005.jpg
# 파일 이동 완료 : David_Brinkley_0001.jpg
# 파일 이동 완료 : Alvaro_Uribe_0008.jpg
# 파일 이동 완료 : Nicolas_Kiefer_0001.jpg
# 파일 이동 완료 : Jay_Garner_0003.jpg
# 파일 이동 완료 : Robert_Woody_Johnson_0001.jpg
# 파일 이동 완료 : Tina_Conner_0001.jpg
# 파일 이동 완료 : Rina_Lazo_0001.jpg
# 파일 이동 완료 : Jack_Straw_0016.jpg
# 파일 이동 완료 : Condoleezza_Rice_0004.jpg
# 파일 이동 완료 : Choi_Sung-hong_0002.jpg
# 파일 이동 완료 : Charles_Moose_0008.jpg
# 파일 이동 완료 : Sean_Penn_0001.jpg
# 파일 이동 완료 : John_Allen_Muhammad_0001.jpg
# 파일 이동 완료 : Don_Hewitt_0001.jpg
# 파일 이동 완료 : Carmen_Electra_0001.jpg
# 파일 이동 완료 : Farida_Ragoonanan_0001.jpg
# 파일 이동 완료 : Tommy_Tubberville_0001.jpg
# 파일 이동 완료 : Bill_Clinton_0011.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0062.jpg
# 파일 이동 완료 : Duncan_Fletcher_0001.jpg
# 파일 이동 완료 : Edmund_Stoiber_0007.jpg
# 파일 이동 완료 : Sergey_Lavrov_0003.jpg
# 파일 이동 완료 : Luiz_Inacio_Lula_da_Silva_0028.jpg
# 파일 이동 완료 : Recep_Tayyip_Erdogan_0017.jpg
# 파일 이동 완료 : Roel_Campos_0001.jpg
# 파일 이동 완료 : Melissa_Joan_Hart_0001.jpg
# 파일 이동 완료 : Eric_Idle_0001.jpg
# 파일 이동 완료 : David_Spade_0001.jpg
# 파일 이동 완료 : Ilan_Ramon_0002.jpg
# 파일 이동 완료 : Linda_Amicangioli_0001.jpg
# 파일 이동 완료 : Tiger_Woods_0010.jpg
# 파일 이동 완료 : Vanessa_Redgrave_0002.jpg
# 파일 이동 완료 : LK_Advani_0003.jpg
# 파일 이동 완료 : Jacques_Chirac_0007.jpg
# 파일 이동 완료 : Bill_Curry_0001.jpg
# 파일 이동 완료 : Georgina_Bardach_0001.jpg
# 파일 이동 완료 : Sebastian_Cuattrin_0001.jpg
# 파일 이동 완료 : Tali_Imani_0001.jpg
# 파일 이동 완료 : Martin_Boryczewski_0001.jpg
# 파일 이동 완료 : Colin_Powell_0012.jpg
# 파일 이동 완료 : Juan_Pablo_Montoya_0008.jpg
# 파일 이동 완료 : Khalid_Khannouchi_0001.jpg
# 파일 이동 완료 : Queen_Elizabeth_II_0013.jpg
# 파일 이동 완료 : Michael_Douglas_0001.jpg
# 파일 이동 완료 : Alanna_Ubach_0001.jpg
# 파일 이동 완료 : Fann_Wong_0001.jpg
# 파일 이동 완료 : Ari_Fleischer_0004.jpg
# 파일 이동 완료 : Jim_Furyk_0004.jpg
# 파일 이동 완료 : Juan_Carlos_Ortega_0001.jpg
# 파일 이동 완료 : Mary_Tyler_Moore_0001.jpg
# 파일 이동 완료 : George_W_Bush_0101.jpg
# 파일 이동 완료 : Katie_Harman_0001.jpg
# 파일 이동 완료 : Taufik_Hidayat_0001.jpg
# 파일 이동 완료 : Michelle_Yeoh_0004.jpg
# 파일 이동 완료 : Sourav_Ganguly_0005.jpg
# 파일 이동 완료 : Nikki_McKibbin_0001.jpg
# 파일 이동 완료 : Lleyton_Hewitt_0040.jpg
# 파일 이동 완료 : Barbara_Brezigar_0002.jpg
# 파일 이동 완료 : Jesse_James_Leija_0001.jpg
# 파일 이동 완료 : Tom_Ridge_0007.jpg
# 파일 이동 완료 : Joerg_Haider_0002.jpg
# 파일 이동 완료 : Nicola_Bono_0001.jpg
# 파일 이동 완료 : Yashwant_Sinha_0004.jpg
# 파일 이동 완료 : Queen_Rania_0005.jpg
# 파일 이동 완료 : Colin_Powell_0113.jpg
# 파일 이동 완료 : Tony_Blair_0035.jpg
# 파일 이동 완료 : Tom_Hanks_0001.jpg
# 파일 이동 완료 : Mike_Weir_0005.jpg
# 파일 이동 완료 : Peter_Hillary_0001.jpg
# 파일 이동 완료 : Janice_Goldfinger_0001.jpg
# 파일 이동 완료 : Elodie_Bouchez_0001.jpg
# 파일 이동 완료 : Karen_Sharpe_Kramer_0001.jpg
# 파일 이동 완료 : Dagmar_Dunlevy_0001.jpg
# 파일 이동 완료 : Steve_Mariucci_0002.jpg
# 파일 이동 완료 : Pervez_Musharraf_0013.jpg
# 파일 이동 완료 : Joe_Torre_0004.jpg
# 파일 이동 완료 : Andre_Agassi_0011.jpg
# 파일 이동 완료 : Silvio_Berlusconi_0030.jpg
# 파일 이동 완료 : Timothy_McVeigh_0001.jpg
# 파일 이동 완료 : Alex_Cejka_0001.jpg
# 파일 이동 완료 : James_Blake_0006.jpg
# 파일 이동 완료 : Catherine_Zeta-Jones_0004.jpg
# 파일 이동 완료 : Jeb_Bush_0003.jpg
# 파일 이동 완료 : Brian_Kerr_0001.jpg
# 파일 이동 완료 : Jolanta_Kwasniewski_0002.jpg
# 파일 이동 완료 : Colin_Powell_0008.jpg
# 파일 이동 완료 : Lina_Krasnoroutskaya_0002.jpg
# 파일 이동 완료 : Amy_Smart_0001.jpg
# 파일 이동 완료 : Justin_Timberlake_0005.jpg
# 파일 이동 완료 : Michael_Jackson_0010.jpg
# 파일 이동 완료 : Paula_Radcliffe_0001.jpg
# 파일 이동 완료 : George_W_Bush_0051.jpg
# 파일 이동 완료 : Cecile_de_France_0001.jpg
# 파일 이동 완료 : Michael_Douglas_0003.jpg
# 파일 이동 완료 : Robert_Tyrrell_0001.jpg
# 파일 이동 완료 : Tammy_Lynn_Michaels_0002.jpg
# 파일 이동 완료 : Doug_Moe_0001.jpg
# 파일 이동 완료 : Richard_Myers_0006.jpg
# 파일 이동 완료 : Dick_Jauron_0001.jpg
# 파일 이동 완료 : Paul_ONeill_0004.jpg
# 파일 이동 완료 : Jennifer_Capriati_0033.jpg
# 파일 이동 완료 : Norm_Coleman_0005.jpg
# 파일 이동 완료 : Tim_Duncan_0004.jpg
# 파일 이동 완료 : Michel_Therrien_0001.jpg
# 파일 이동 완료 : Ana_Paula_Gerard_0001.jpg
# 파일 이동 완료 : Agnelo_Queiroz_0001.jpg
# 파일 이동 완료 : Ren_Qingjin_0001.jpg
# 파일 이동 완료 : Peter_Struck_0005.jpg
# 파일 이동 완료 : Britney_Spears_0007.jpg
# 파일 이동 완료 : Tim_Pawlenty_0001.jpg
# 파일 이동 완료 : Zoran_Djindjic_0002.jpg
# 파일 이동 완료 : John_Malkovich_0003.jpg
# 파일 이동 완료 : Erika_Reyes_0001.jpg
# 파일 이동 완료 : Alex_Penelas_0001.jpg
# 파일 이동 완료 : Markus_Naslund_0002.jpg
# 파일 이동 완료 : Naomi_Watts_0006.jpg
# 파일 이동 완료 : George_W_Bush_0422.jpg
# 파일 이동 완료 : Lon_Kruger_0001.jpg
# 파일 이동 완료 : Robert_Morvillo_0001.jpg
# 파일 이동 완료 : Eliott_Spitzer_0001.jpg
# 파일 이동 완료 : Richard_Gephardt_0002.jpg
# 파일 이동 완료 : Recep_Tayyip_Erdogan_0003.jpg
# 파일 이동 완료 : Jen_Schefft_0001.jpg
# 파일 이동 완료 : William_Ford_Jr_0004.jpg
# 파일 이동 완료 : Edward_Seaga_0001.jpg
# 파일 이동 완료 : James_Harris_0001.jpg
# 파일 이동 완료 : David_Braley_0001.jpg
# 파일 이동 완료 : Bridget_Fonda_0002.jpg
# 파일 이동 완료 : Kofi_Annan_0018.jpg
# 파일 이동 완료 : Atal_Bihari_Vajpayee_0022.jpg
# 파일 이동 완료 : Tony_Blair_0041.jpg
# 파일 이동 완료 : Guangdong_Ou_Guangyuan_0001.jpg
# 파일 이동 완료 : Laura_Bush_0013.jpg
# 파일 이동 완료 : Anna_Kournikova_0010.jpg
# 파일 이동 완료 : James_Gibson_0001.jpg
# 파일 이동 완료 : Ariel_Sharon_0049.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0035.jpg
# 파일 이동 완료 : Greg_Kinnear_0001.jpg
# 파일 이동 완료 : Brad_Johnson_0002.jpg
# 파일 이동 완료 : Tony_Blair_0139.jpg
# 파일 이동 완료 : Jim_Otto_0001.jpg
# 파일 이동 완료 : Michel_Kratochvil_0001.jpg
# 파일 이동 완료 : Pedro_Almodovar_0007.jpg
# 파일 이동 완료 : Klaus_Zwickel_0001.jpg
# 파일 이동 완료 : John_Bolton_0017.jpg
# 파일 이동 완료 : Larry_Brown_0003.jpg
# 파일 이동 완료 : Michael_Denzel_0001.jpg
# 파일 이동 완료 : Intisar_Ajouri_0003.jpg
# 파일 이동 완료 : Allen_Rock_0001.jpg
# 파일 이동 완료 : Antonio_Palocci_0007.jpg
# 파일 이동 완료 : Jiang_Zemin_0016.jpg
# 파일 이동 완료 : Mike_Krzyzewski_0001.jpg
# 파일 이동 완료 : Guillermo_Coria_0026.jpg
# 파일 이동 완료 : Cindy_Zagorski_0001.jpg
# 파일 이동 완료 : Yukiko_Okudo_0002.jpg
# 파일 이동 완료 : Brad_Pitt_0001.jpg
# 파일 이동 완료 : Moon-So-ri_0001.jpg
# 파일 이동 완료 : Jim_Fassel_0001.jpg
# 파일 이동 완료 : Angel_Maza_0001.jpg
# 파일 이동 완료 : Maria_Luisa_Mendonca_0001.jpg
# 파일 이동 완료 : Philip_Murtaugh_0001.jpg
# 파일 이동 완료 : Mireya_Moscoso_0003.jpg
# 파일 이동 완료 : Eric_Hinske_0002.jpg
# 파일 이동 완료 : Michael_Pfleger_0001.jpg
# 파일 이동 완료 : Spencer_Abraham_0010.jpg
# 파일 이동 완료 : Adam_Scott_0002.jpg
# 파일 이동 완료 : Hamid_Karzai_0015.jpg
# 파일 이동 완료 : Paul_Gascoigne_0003.jpg
# 파일 이동 완료 : Art_Cooper_0001.jpg
# 파일 이동 완료 : Pauline_Phillips_0001.jpg
# 파일 이동 완료 : Laura_Pausini_0001.jpg
# 파일 이동 완료 : George_W_Bush_0398.jpg
# 파일 이동 완료 : Phil_Bredesen_0001.jpg
# 파일 이동 완료 : Sonia_Lopez_0001.jpg
# 파일 이동 완료 : Franck_Cerutti_0001.jpg
# 파일 이동 완료 : Jeffrey_Archer_0001.jpg
# 파일 이동 완료 : Randy_Jackson_0001.jpg
# 파일 이동 완료 : Kathryn_Grayson_0001.jpg
# 파일 이동 완료 : Jean_Chretien_0040.jpg
# 파일 이동 완료 : Jacques_Villeneuve_0001.jpg
# 파일 이동 완료 : Carlos_Moya_0007.jpg
# 파일 이동 완료 : Fernando_Vargas_0001.jpg
# 파일 이동 완료 : Renee_Zellweger_0007.jpg
# 파일 이동 완료 : Phan_Van_Khai_0001.jpg
# 파일 이동 완료 : Mahathir_Mohamad_0013.jpg
# 파일 이동 완료 : Feliciano_Lopez_0001.jpg
# 파일 이동 완료 : Barbra_Streisand_0001.jpg
# 파일 이동 완료 : Munir_Akram_0002.jpg
# 파일 이동 완료 : Slobodan_Milosevic_0004.jpg
# 파일 이동 완료 : Vince_Carter_0001.jpg
# 파일 이동 완료 : Michael_Jordan_0002.jpg
# 파일 이동 완료 : Abdel_Nasser_Assidi_0001.jpg
# 파일 이동 완료 : George_W_Bush_0223.jpg
# 파일 이동 완료 : Scott_McNealy_0002.jpg
# 파일 이동 완료 : Michael_Rolinee_0001.jpg
# 파일 이동 완료 : Richard_Gephardt_0004.jpg
# 파일 이동 완료 : Alejandro_Avila_0002.jpg
# 파일 이동 완료 : Dora_Bakoyianni_0001.jpg
# 파일 이동 완료 : Juan_Ignacio_Chela_0003.jpg
# 파일 이동 완료 : Greg_Owen_0002.jpg
# 파일 이동 완료 : Diana_Ross_0001.jpg
# 파일 이동 완료 : Lindsay_Davenport_0020.jpg
# 파일 이동 완료 : Li_Peng_0004.jpg
# 파일 이동 완료 : Eddie_Lewis_0001.jpg
# 파일 이동 완료 : Cemil_Cicek_0001.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0031.jpg
# 파일 이동 완료 : Winona_Ryder_0024.jpg
# 파일 이동 완료 : Ron_Dittemore_0002.jpg
# 파일 이동 완료 : Luiz_Inacio_Lula_da_Silva_0037.jpg
# 파일 이동 완료 : Alvaro_Uribe_0023.jpg
# 파일 이동 완료 : Torri_Edwards_0002.jpg
# 파일 이동 완료 : William_Martin_0001.jpg
# 파일 이동 완료 : Renee_Zellweger_0012.jpg
# 파일 이동 완료 : Maria_Soledad_Alvear_Valenzuela_0003.jpg
# 파일 이동 완료 : Buford_Blount_0001.jpg
# 파일 이동 완료 : Celine_Dion_0007.jpg
# 파일 이동 완료 : Wallace_Capel_0001.jpg
# 파일 이동 완료 : Kristen_Rivera_0001.jpg
# 파일 이동 완료 : Garry_Alejano_0001.jpg
# 파일 이동 완료 : Jennifer_Lopez_0006.jpg
# 파일 이동 완료 : Adam_Freier_0001.jpg
# 파일 이동 완료 : Ernesto_Zedillo_0002.jpg
# 파일 이동 완료 : Vyacheslav_Fetisov_0001.jpg
# 파일 이동 완료 : Robert_Mueller_0003.jpg
# 파일 이동 완료 : Brian_Schneider_0001.jpg
# 파일 이동 완료 : Edward_Norton_0001.jpg
# 파일 이동 완료 : Joe_Friedberg_0001.jpg
# 파일 이동 완료 : George_W_Bush_0425.jpg
# 파일 이동 완료 : Mario_Alfaro-Lopez_0001.jpg
# 파일 이동 완료 : Carlos_Moya_0008.jpg
# 파일 이동 완료 : Matthew_During_0001.jpg
# 파일 이동 완료 : James_Spalding_0001.jpg
# 파일 이동 완료 : Qazi_Hussain_Ahmed_0001.jpg
# 파일 이동 완료 : Alan_Ball_0002.jpg
# 파일 이동 완료 : Robert_Gallo_0001.jpg
# 파일 이동 완료 : Joaquim_Levy_0001.jpg
# 파일 이동 완료 : Claire_Danes_0003.jpg
# 파일 이동 완료 : Mike_Bryan_0001.jpg
# 파일 이동 완료 : Yoelbi_Quesada_0001.jpg
# 파일 이동 완료 : Mark_Philippoussis_0009.jpg
# 파일 이동 완료 : Desmon_Farmer_0001.jpg
# 파일 이동 완료 : E_Clay_Shaw_0001.jpg
# 파일 이동 완료 : Michelle_Collins_0002.jpg
# 파일 이동 완료 : Kirsten_Clark_0001.jpg
# 파일 이동 완료 : Mukhtar_Alytnbayev_0001.jpg
# 파일 이동 완료 : Yao_Ming_0002.jpg
# 파일 이동 완료 : Tony_Blair_0108.jpg
# 파일 이동 완료 : James_Ballenger_0001.jpg
# 파일 이동 완료 : Ariel_Sharon_0065.jpg
# 파일 이동 완료 : Hugo_Chavez_0006.jpg
# 파일 이동 완료 : Mark_Philippoussis_0007.jpg
# 파일 이동 완료 : Paula_Zahn_0001.jpg
# 파일 이동 완료 : Juan_Manuel_Marquez_0001.jpg
# 파일 이동 완료 : David_Nalbandian_0011.jpg
# 파일 이동 완료 : Ricardo_Maduro_0002.jpg
# 파일 이동 완료 : Colin_Powell_0206.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0010.jpg
# 파일 이동 완료 : Manuel_Poggiali_0001.jpg
# 파일 이동 완료 : Meryl_Streep_0004.jpg
# 파일 이동 완료 : James_Kelly_0001.jpg
# 파일 이동 완료 : Carlos_Menem_0006.jpg
# 파일 이동 완료 : Goh_Kun_0002.jpg
# 파일 이동 완료 : Don_Siegelman_0004.jpg
# 파일 이동 완료 : Bill_Clinton_0015.jpg
# 파일 이동 완료 : Bruce_Weber_0001.jpg
# 파일 이동 완료 : Jim_Leach_0001.jpg
# 파일 이동 완료 : Natalie_Williams_0001.jpg
# 파일 이동 완료 : Catherine_Zeta-Jones_0003.jpg
# 파일 이동 완료 : Marcelo_Ebrard_0001.jpg
# 파일 이동 완료 : Theodore_Tweed_Roosevelt_0001.jpg
# 파일 이동 완료 : Bob_Newhart_0001.jpg
# 파일 이동 완료 : Rachel_Kempson_0001.jpg
# 파일 이동 완료 : William_Rehnquist_0001.jpg
# 파일 이동 완료 : Richard_Armitage_0006.jpg
# 파일 이동 완료 : Richard_Gere_0002.jpg
# 파일 이동 완료 : Robert_De_Niro_0004.jpg
# 파일 이동 완료 : Thomas_Haeggstroem_0001.jpg
# 파일 이동 완료 : Rachel_Wheatley_0001.jpg
# 파일 이동 완료 : Bill_Graham_0005.jpg
# 파일 이동 완료 : Sean_Hayes_0001.jpg
# 파일 이동 완료 : Koichiro_Matsuura_0001.jpg
# 파일 이동 완료 : Jean_Chretien_0055.jpg
# 파일 이동 완료 : Tom_Cruise_0004.jpg
# 파일 이동 완료 : Hans_Leistritz_0001.jpg
# 파일 이동 완료 : Francois_Pienaar_0001.jpg
# 파일 이동 완료 : Liv_Tyler_0001.jpg
# 파일 이동 완료 : Bud_Selig_0004.jpg
# 파일 이동 완료 : Tom_Brady_0001.jpg
# 파일 이동 완료 : Binyamin_Ben-Eliezer_0001.jpg
# 파일 이동 완료 : Hans_Blix_0034.jpg
# 파일 이동 완료 : Tom_Ridge_0015.jpg
# 파일 이동 완료 : Ai_Sugiyama_0001.jpg
# 파일 이동 완료 : Ann_Godbehere_0001.jpg
# 파일 이동 완료 : Rita_Grande_0001.jpg
# 파일 이동 완료 : Marieta_Chrousala_0001.jpg
# 파일 이동 완료 : Abel_Pacheco_0004.jpg
# 파일 이동 완료 : Vladimir_Putin_0021.jpg
# 파일 이동 완료 : Tamara_Mowry_0001.jpg
# 파일 이동 완료 : George_Ryan_0001.jpg
# 파일 이동 완료 : Marquis_Estill_0001.jpg
# 파일 이동 완료 : Jeff_Van_Gundy_0001.jpg
# 파일 이동 완료 : Lester_Holt_0001.jpg
# 파일 이동 완료 : Paul_Kariya_0001.jpg
# 파일 이동 완료 : John_Paul_II_0002.jpg
# 파일 이동 완료 : Paul_Bremer_0012.jpg
# 파일 이동 완료 : Mohammad_Khatami_0002.jpg
# 파일 이동 완료 : Nestor_Kirchner_0009.jpg
# 파일 이동 완료 : Brandon_Lloyd_0001.jpg
# 파일 이동 완료 : Guy_Hemmings_0002.jpg
# 파일 이동 완료 : John_Madden_0001.jpg
# 파일 이동 완료 : Pete_Sampras_0016.jpg
# 파일 이동 완료 : Tony_Blair_0081.jpg
# 파일 이동 완료 : Katie_Smith_0001.jpg
# 파일 이동 완료 : Eddy_Merckx_0001.jpg
# 파일 이동 완료 : Laura_Bush_0037.jpg
# 파일 이동 완료 : Cedric_Benson_0001.jpg
# 파일 이동 완료 : Sammy_Sosa_0002.jpg
# 파일 이동 완료 : James_Meredeth_0001.jpg
# 파일 이동 완료 : Jose_Sarney_0001.jpg
# 파일 이동 완료 : Charles_Moose_0013.jpg
# 파일 이동 완료 : Muhammad_Saeed_al-Sahhaf_0004.jpg
# 파일 이동 완료 : Mike_Flanagan_0001.jpg

# %%
## "본인 얼굴"에 대한 파일 리스트의 상위 5개 조회
img_list_my[:5]
# Out:
# ['/content/my_face/my_face_370 - ║╣╗τ║╗ (4) - ║╣╗τ║╗ - ║╣╗τ║╗.jpg',
#  '/content/my_face/my_face_25 - ║╣╗τ║╗ - ║╣╗τ║╗ (2).jpg',
#  '/content/my_face/my_face_133 - ║╣╗τ║╗ (4).jpg',
#  '/content/my_face/my_face_435 - ║╣╗τ║╗ - ║╣╗τ║╗ - ║╣╗τ║╗.jpg',
#  '/content/my_face/my_face_202 - ║╣╗τ║╗ - ║╣╗τ║╗.jpg']

# %%
print('Training data의 my_face 이미지 수 : ', len(os.listdir('/content/tr_data/my')))
print('Training data의 other_face 이미지 수 : ', len(os.listdir('/content/tr_data/other')))

print('Test data의 my_face 이미지 수 : ', len(os.listdir('/content/te_data/my')))
print('Test data의 other_face 이미지 수 : ', len(os.listdir('/content/te_data/other')))
# Out:
# Training data의 my_face 이미지 수 :  8800
# Training data의 other_face 이미지 수 :  8800
# Test data의 my_face 이미지 수 :  2200
# Test data의 other_face 이미지 수 :  2200

# %% [markdown]
# #### 2) **특정 함수** 사용

# %%
## Training set 데이터 폴더를 데이터셋화
## 이 과정에서 Validation set도 생성
tr_idfd, val_idfd = image_dataset_from_directory(tr_data,                    ## Training 폴더 경로
                                                 class_names=['other','my'], ## 클래스 순서 지정
                                                 batch_size=32,              ## 이미지 덩어리 단위
                                                 image_size=(160,160),       ## 이미지 리사이즈
                                                 shuffle=True,               ## 섞어야 올바르게 분할됨
                                                 seed=2024,                  ## 재현성
                                                 validation_split=0.3,       ## 데이터 스플릿 비율
                                                 subset='both',              ## 데이터셋 나눔 방식
                                                 )
# Out:
# Found 17600 files belonging to 2 classes.
# Using 12320 files for training.
# Using 5280 files for validation.

# %%
## Test set 데이터 폴더를 데이터셋화
te_idfd = image_dataset_from_directory(te_data,                    ## Test 폴더 경로
                                       class_names=['other','my'], ## 클래스 순서 지정
                                       batch_size=32,              ## 이미지 덩어리 단위
                                       image_size=(160,160),       ## 이미지 리사이즈
                                       shuffle=True,               ## 섞어야 올바르게 분할됨
                                       seed=2024                   ## 재현성
                                       )
# Out:
# Found 4400 files belonging to 2 classes.

# %%
## 위에서 만든 이미지 데이터 덩어리가 몇 개인지 확인
len(tr_idfd), len(val_idfd)
# Out:
# (385, 165)

# %% [markdown]
# #### 3) 스케일링

# %%
def rescale(image, label) :
    image = image / 255
    return image, label

# %%
tr_idfd_rescale = tr_idfd.map(rescale)
val_idfd_rescale = val_idfd.map(rescale)
te_idfd_rescale = te_idfd.map(rescale)

# %% [markdown]
# ## 4.미션2

# %% [markdown]
# 데이터셋을 **학습에 적합한 형태**로 만들었다면, **FaceNet 모델로 Transfer Learning**을 수행합니다.
#
# - 1) FaceNet 모델 구조를 생성합니다.
#     - [FaceNet 논문 링크](https://arxiv.org/abs/1503.03832)
#     - FaceNet의 Input은 (160, 160) 사이즈의 이미지입니다.
# - 2) FaceNet 모델 구조 + 구조 추가
#     - FaceNet의 Output은 128차원의 벡터입니다.
#     - 이 과정을 Transfer Learning라고 합니다.

# %% [markdown]
# ### (1) FaceNet 구조 생성

# %% [markdown]
# * **세부 요구사항**
#     - FaceNet의 구조를 생성합니다.
#         - FaceNet 구조 생성에 필요한 함수를 만듭니다.
#     - FaceNet의 구조에 **잘 학습된 가중치**를 부여합니다.
#         - FaceNet 원본 가중치 파일을 공유하였습니다.
#     - (선택사항) FaceNet 모델의 가중치 업데이트를 방지합니다.
#     - 예시 코드에서 사용한 라이브러리
#         - numpy, functools, keras

# %% [markdown]
# #### 1) 모델 구조 생성

# %%
import numpy as np
from functools import partial


import keras
from keras.models import Model

from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Activation
from keras.layers import BatchNormalization, Dropout, GlobalAveragePooling2D
from keras.layers import Lambda, Concatenate, add

from keras import backend as K
from keras.saving import register_keras_serializable

# %%
## 3.6.0.dev2024100303 OK
## 3.6.0 dev2024101103
keras.__version__
# Out:
# '3.7.0.dev2024110103'

# %%
@register_keras_serializable()
def scaling(x, scale):
    return x * scale

@register_keras_serializable()
def conv2d_bn(x,
              filters,
              kernel_size,
              strides=1,
              padding='same',
              activation='relu',
              use_bias=False,
              name=None):
    x = Conv2D(filters,
               kernel_size,
               strides=strides,
               padding=padding,
               use_bias=use_bias,
               name=name)(x)
    if not use_bias:
        bn_axis = 1 if K.image_data_format() == 'channels_first' else 3
        bn_name = _generate_layer_name('BatchNorm', prefix=name)
        x = BatchNormalization(axis=bn_axis, momentum=0.995, epsilon=0.001,
                               scale=False, name=bn_name)(x)
    if activation is not None:
        ac_name = _generate_layer_name('Activation', prefix=name)
        x = Activation(activation, name=ac_name)(x)
    return x

@register_keras_serializable()
def _generate_layer_name(name, branch_idx=None, prefix=None):
    if prefix is None:
        return None
    if branch_idx is None:
        return '_'.join((prefix, name))
    return '_'.join((prefix, 'Branch', str(branch_idx), name))

@register_keras_serializable()
def _inception_resnet_block(x, scale, block_type, block_idx, activation='relu'):
    channel_axis = 1 if K.image_data_format() == 'channels_first' else 3
    if block_idx is None:
        prefix = None
    else:
        prefix = '_'.join((block_type, str(block_idx)))
    name_fmt = partial(_generate_layer_name, prefix=prefix)

    if block_type == 'Block35':
        branch_0 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 32, 3, name=name_fmt('Conv2d_0b_3x3', 1))
        branch_2 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_0a_1x1', 2))
        branch_2 = conv2d_bn(branch_2, 32, 3, name=name_fmt('Conv2d_0b_3x3', 2))
        branch_2 = conv2d_bn(branch_2, 32, 3, name=name_fmt('Conv2d_0c_3x3', 2))
        branches = [branch_0, branch_1, branch_2]
    elif block_type == 'Block17':
        branch_0 = conv2d_bn(x, 128, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 128, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 128, [1, 7], name=name_fmt('Conv2d_0b_1x7', 1))
        branch_1 = conv2d_bn(branch_1, 128, [7, 1], name=name_fmt('Conv2d_0c_7x1', 1))
        branches = [branch_0, branch_1]
    elif block_type == 'Block8':
        branch_0 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 192, [1, 3], name=name_fmt('Conv2d_0b_1x3', 1))
        branch_1 = conv2d_bn(branch_1, 192, [3, 1], name=name_fmt('Conv2d_0c_3x1', 1))
        branches = [branch_0, branch_1]
    else:
        raise ValueError('Unknown Inception-ResNet block type. '
                         'Expects "Block35", "Block17" or "Block8", '
                         'but got: ' + str(block_type))

    mixed = Concatenate(axis=channel_axis, name=name_fmt('Concatenate'))(branches)
    up = conv2d_bn(mixed,
                #    K.int_shape(x)[channel_axis],
                   x.shape[channel_axis],
                   1,
                   activation=None,
                   use_bias=True,
                   name=name_fmt('Conv2d_1x1'))
    up = Lambda(scaling,
                # output_shape=K.int_shape(up)[1:],
                output_shape=up.shape[1:],
                arguments={'scale': scale})(up)
    x = add([x, up])
    if activation is not None:
        x = Activation(activation, name=name_fmt('Activation'))(x)
    return x

# %%
@register_keras_serializable()
def InceptionResNetV1(input_shape=(160, 160, 3),
                      classes=128,
                      dropout_keep_prob=0.8,
                      weights_path=None):
    inputs = Input(shape=input_shape)
    x = conv2d_bn(inputs, 32, 3, strides=2, padding='valid', name='Conv2d_1a_3x3')
    x = conv2d_bn(x, 32, 3, padding='valid', name='Conv2d_2a_3x3')
    x = conv2d_bn(x, 64, 3, name='Conv2d_2b_3x3')
    x = MaxPooling2D(3, strides=2, name='MaxPool_3a_3x3')(x)
    x = conv2d_bn(x, 80, 1, padding='valid', name='Conv2d_3b_1x1')
    x = conv2d_bn(x, 192, 3, padding='valid', name='Conv2d_4a_3x3')
    x = conv2d_bn(x, 256, 3, strides=2, padding='valid', name='Conv2d_4b_3x3')

    # 5x Block35 (Inception-ResNet-A block):
    for block_idx in range(1, 6):
        x = _inception_resnet_block(x,
                                    scale=0.17,
                                    block_type='Block35',
                                    block_idx=block_idx)

    # Mixed 6a (Reduction-A block):
    channel_axis = 1 if K.image_data_format() == 'channels_first' else 3
    name_fmt = partial(_generate_layer_name, prefix='Mixed_6a')
    branch_0 = conv2d_bn(x,
                         384,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 0))
    branch_1 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_0a_1x1', 1))
    branch_1 = conv2d_bn(branch_1, 192, 3, name=name_fmt('Conv2d_0b_3x3', 1))
    branch_1 = conv2d_bn(branch_1,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 1))
    branch_pool = MaxPooling2D(3,
                               strides=2,
                               padding='valid',
                               name=name_fmt('MaxPool_1a_3x3', 2))(x)
    branches = [branch_0, branch_1, branch_pool]
    x = Concatenate(axis=channel_axis, name='Mixed_6a')(branches)

    # 10x Block17 (Inception-ResNet-B block):
    for block_idx in range(1, 11):
        x = _inception_resnet_block(x,
                                    scale=0.1,
                                    block_type='Block17',
                                    block_idx=block_idx)

    # Mixed 7a (Reduction-B block): 8 x 8 x 2080
    name_fmt = partial(_generate_layer_name, prefix='Mixed_7a')
    branch_0 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 0))
    branch_0 = conv2d_bn(branch_0,
                         384,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 0))
    branch_1 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 1))
    branch_1 = conv2d_bn(branch_1,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 1))
    branch_2 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 2))
    branch_2 = conv2d_bn(branch_2, 256, 3, name=name_fmt('Conv2d_0b_3x3', 2))
    branch_2 = conv2d_bn(branch_2,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 2))
    branch_pool = MaxPooling2D(3,
                               strides=2,
                               padding='valid',
                               name=name_fmt('MaxPool_1a_3x3', 3))(x)
    branches = [branch_0, branch_1, branch_2, branch_pool]
    x = Concatenate(axis=channel_axis, name='Mixed_7a')(branches)

    # 5x Block8 (Inception-ResNet-C block):
    for block_idx in range(1, 6):
        x = _inception_resnet_block(x,
                                    scale=0.2,
                                    block_type='Block8',
                                    block_idx=block_idx)
    x = _inception_resnet_block(x,
                                scale=1.,
                                activation=None,
                                block_type='Block8',
                                block_idx=6)

    # Classification block
    x = GlobalAveragePooling2D(name='AvgPool')(x)
    x = Dropout(1.0 - dropout_keep_prob, name='Dropout')(x)
    # Bottleneck
    x = Dense(classes, use_bias=False, name='Bottleneck')(x)
    bn_name = _generate_layer_name('BatchNorm', prefix='Bottleneck')
    x = BatchNormalization(momentum=0.995, epsilon=0.001, scale=False,
                           name=bn_name)(x)

    # Create model
    model = Model(inputs, x, name='inception_resnet_v1')
    if weights_path is not None:
        model.load_weights(weights_path)

    return model

# %%
## FaceNet 구조 생성 코드
facenet_model = InceptionResNetV1()

# %%
## FaceNet 구조의 전체 레이어 길이
len(facenet_model.layers)
# Out:
# 447

# %%
## FaceNet 전체 구조 확인
facenet_model.summary()
# Out:
# Model: "inception_resnet_v1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 160, 160, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3 (Conv2D)    │ (None, 79, 79, 32)     │            864 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3_BatchNorm   │ (None, 79, 79, 32)     │             96 │ Conv2d_1a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3_Activation  │ (None, 79, 79, 32)     │              0 │ Conv2d_1a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3 (Conv2D)    │ (None, 77, 77, 32)     │          9,216 │ Conv2d_1a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3_BatchNorm   │ (None, 77, 77, 32)     │             96 │ Conv2d_2a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3_Activation  │ (None, 77, 77, 32)     │              0 │ Conv2d_2a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3 (Conv2D)    │ (None, 77, 77, 64)     │         18,432 │ Conv2d_2a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3_BatchNorm   │ (None, 77, 77, 64)     │            192 │ Conv2d_2b_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3_Activation  │ (None, 77, 77, 64)     │              0 │ Conv2d_2b_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ MaxPool_3a_3x3            │ (None, 38, 38, 64)     │              0 │ Conv2d_2b_3x3_Activat… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1 (Conv2D)    │ (None, 38, 38, 80)     │          5,120 │ MaxPool_3a_3x3[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1_BatchNorm   │ (None, 38, 38, 80)     │            240 │ Conv2d_3b_1x1[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1_Activation  │ (None, 38, 38, 80)     │              0 │ Conv2d_3b_1x1_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3 (Conv2D)    │ (None, 36, 36, 192)    │        138,240 │ Conv2d_3b_1x1_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3_BatchNorm   │ (None, 36, 36, 192)    │            576 │ Conv2d_4a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3_Activation  │ (None, 36, 36, 192)    │              0 │ Conv2d_4a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3 (Conv2D)    │ (None, 17, 17, 256)    │        442,368 │ Conv2d_4a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3_BatchNorm   │ (None, 17, 17, 256)    │            768 │ Conv2d_4b_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3_Activation  │ (None, 17, 17, 256)    │              0 │ Conv2d_4b_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_1_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_1_Branch_1_Co… │
# │                           │                        │                │ Block35_1_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_1_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 17, 17, 256)    │              0 │ Block35_1_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 17, 17, 256)    │              0 │ Conv2d_4b_3x3_Activat… │
# │                           │                        │                │ lambda[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Activation      │ (None, 17, 17, 256)    │              0 │ add[0][0]              │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_2_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_2_Branch_1_Co… │
# │                           │                        │                │ Block35_2_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_2_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_1 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_2_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_1_Activation[… │
# │                           │                        │                │ lambda_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Activation      │ (None, 17, 17, 256)    │              0 │ add_1[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_3_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_3_Branch_1_Co… │
# │                           │                        │                │ Block35_3_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_3_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_2 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_3_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_2_Activation[… │
# │                           │                        │                │ lambda_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Activation      │ (None, 17, 17, 256)    │              0 │ add_2[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_4_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_4_Branch_1_Co… │
# │                           │                        │                │ Block35_4_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_4_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_3 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_4_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_3_Activation[… │
# │                           │                        │                │ lambda_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Activation      │ (None, 17, 17, 256)    │              0 │ add_3[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_5_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_5_Branch_1_Co… │
# │                           │                        │                │ Block35_5_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_5_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_4 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_5_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_4_Activation[… │
# │                           │                        │                │ lambda_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Activation      │ (None, 17, 17, 256)    │              0 │ add_4[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │         49,152 │ Block35_5_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │            576 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │        331,776 │ Mixed_6a_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │            576 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │        884,736 │ Block35_5_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │        442,368 │ Mixed_6a_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │          1,152 │ Mixed_6a_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │            768 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │              0 │ Mixed_6a_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_2_MaxPoo… │ (None, 8, 8, 256)      │              0 │ Block35_5_Activation[… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a (Concatenate)    │ (None, 8, 8, 896)      │              0 │ Mixed_6a_Branch_0_Con… │
# │                           │                        │                │ Mixed_6a_Branch_1_Con… │
# │                           │                        │                │ Mixed_6a_Branch_2_Max… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Mixed_6a[0][0]         │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Block17_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Mixed_6a[0][0]         │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Block17_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Concatenate     │ (None, 8, 8, 256)      │              0 │ Block17_1_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block17_1_Branch_1_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Conv2d_1x1      │ (None, 8, 8, 896)      │        230,272 │ Block17_1_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_5 (Lambda)         │ (None, 8, 8, 896)      │              0 │ Block17_1_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 8, 8, 896)      │              0 │ Mixed_6a[0][0],        │
# │                           │                        │                │ lambda_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Activation      │ (None, 8, 8, 896)      │              0 │ add_5[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...
# │ add_17 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_2_Activation[0… │
# │                           │                        │                │ lambda_17[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_3_Activation       │ (None, 3, 3, 1792)     │              0 │ add_17[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_3_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_4_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_3_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_4_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_4_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_4_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_4_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_18 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_4_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_18 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_3_Activation[0… │
# │                           │                        │                │ lambda_18[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Activation       │ (None, 3, 3, 1792)     │              0 │ add_18[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_4_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_5_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_4_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_5_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_5_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_5_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_5_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_19 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_5_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_19 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_4_Activation[0… │
# │                           │                        │                │ lambda_19[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Activation       │ (None, 3, 3, 1792)     │              0 │ add_19[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_5_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_6_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_5_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_6_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_6_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_6_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_6_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_20 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_6_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_20 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_5_Activation[0… │
# │                           │                        │                │ lambda_20[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ AvgPool                   │ (None, 1792)           │              0 │ add_20[0][0]           │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Dropout (Dropout)         │ (None, 1792)           │              0 │ AvgPool[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Bottleneck (Dense)        │ (None, 128)            │        229,376 │ Dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Bottleneck_BatchNorm      │ (None, 128)            │            384 │ Bottleneck[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 22,808,144 (87.01 MB)
#  Trainable params: 22,779,312 (86.90 MB)
#  Non-trainable params: 28,832 (112.62 KB)

# %% [markdown]
# #### 2) 모델에 가중치 적용

# %%
## FaceNet 가중치 파일 경로 설정
weights_path = os.path.join('/content/drive/MyDrive/project4/Datasets/Keras/facenet_model_weights.npz' )
weights_path
# Out:
# '/content/drive/MyDrive/project4/Datasets/Keras/facenet_model_weights.npz'

# %%
## 가중치 파일 불러오기
loaded_weights = np.load(weights_path)

loaded_weights
# Out:
# NpzFile '/content/drive/MyDrive/project4/Datasets/Keras/facenet_model_weights.npz' with keys: arr_0, arr_1, arr_2, arr_3, arr_4...

# %%
## FaceNet 각 레이어에 가중치 적용
facenet_model.set_weights([loaded_weights[key] for key in loaded_weights])

# %% [markdown]
# #### 3) 모델의 가중치 업데이트 방지 (선택사항)

# %%
## FaceNet 전체 레이어에서 마지막 4개의 레이어 확인
facenet_model.layers[-4:]
# Out:
# [<GlobalAveragePooling2D name=AvgPool, built=True>,
#  <Dropout name=Dropout, built=True>,
#  <Dense name=Bottleneck, built=True>,
#  <BatchNormalization name=Bottleneck_BatchNorm, built=True>]

# %%
## FaceNet 전체 레이어에서 마지막 4개의 레이어에만 가중치 업데이트 적용
for l in facenet_model.layers[:-4] :
    l.trainable = False

# %% [markdown]
# ### (2) 모델 구조 변형

# %% [markdown]
# * **세부 요구사항**
#     - 우리의 문제에 맞게 모델을 변형해야 합니다.
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 추가 모델링

# %%
## FaceNet 모델에 이진 분류용 레이어 하나 추가
K.clear_session()

custom_model = keras.models.Sequential()

custom_model.add(facenet_model)
custom_model.add(Dense(1, activation='sigmoid') )

# %%
custom_model.summary() ## keras-nightly로는 정상 작동
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ inception_resnet_v1 (Functional)     │ (None, 128)                 │      22,808,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 22,808,273 (87.01 MB)
#  Trainable params: 229,633 (897.00 KB)
#  Non-trainable params: 22,578,640 (86.13 MB)

# %%
custom_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy', 'precision', 'recall']
                     )

# %% [markdown]
# ## 5.미션3

# %% [markdown]
# 학습된 모델로 추론하여 성능 지표를 확인하고 모델을 개선시키세요.
#
# 그 후, 모델의 구조와 가중치를 **반드시 저장**하여 여러분의 노트북에 옮기세요.
#
# - 1) 다양한 모델을 사용해보세요.
#     - 모델에 정해진 정답은 없습니다.
#     - 성능 지표에서 무엇이 중요한지 깊게 생각하세요.
#     - 사전 학습된 FaceNet 모델을 사용하셔도 좋고, 아예 독창적으로 여러분만의 모델을 만드셔도 좋습니다!
# - 2) 모델을 **반드시 저장**하세요.
#     - .keras 형태로 우선 Colab에 저장하세요.
#     - Colab에 생성된 .keras 파일을 **로컬에 다운로드** 합니다.

# %% [markdown]
# ### (1) 모델 학습

# %% [markdown]
# * **세부 요구사항**
#     - 모델 구조를 잘 변형하였다면, 학습도 진행해야 합니다.
#         - Keras에서 지원하는 다양한 함수를 사용하세요.
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 학습에 유용한 함수 불러오기

# %%
from keras.callbacks import EarlyStopping

# %%
## 얼리스토핑 설정
es = EarlyStopping(patience=4, verbose=1, restore_best_weights=True)

# %% [markdown]
# #### 2) 모델 학습

# %%
## 모델 학습
custom_model.fit(tr_idfd, validation_data=val_idfd,
                 epochs=100, verbose=1,
                 class_weight={0:1, 1:2}, ## 클래스 1에 대해 가중치를 더 주려는 의도
                 callbacks=[es]
                 )
# Out:
# Epoch 1/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 35s 43ms/step - accuracy: 0.9684 - loss: 0.1036 - precision: 0.9586 - recall: 0.9800 - val_accuracy: 0.9975 - val_loss: 0.0085 - val_precision: 1.0000 - val_recall: 0.9950
# Epoch 2/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.9958 - loss: 0.0176 - precision: 0.9935 - recall: 0.9982 - val_accuracy: 0.9996 - val_loss: 0.0014 - val_precision: 0.9992 - val_recall: 1.0000
# Epoch 3/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9961 - loss: 0.0155 - precision: 0.9948 - recall: 0.9975 - val_accuracy: 0.9994 - val_loss: 0.0011 - val_precision: 0.9988 - val_recall: 1.0000
# Epoch 4/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.9986 - loss: 0.0074 - precision: 0.9979 - recall: 0.9994 - val_accuracy: 0.9998 - val_loss: 4.3552e-04 - val_precision: 0.9996 - val_recall: 1.0000
# Epoch 5/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.9970 - loss: 0.0115 - precision: 0.9959 - recall: 0.9982 - val_accuracy: 1.0000 - val_loss: 6.2214e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 6/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9973 - loss: 0.0092 - precision: 0.9961 - recall: 0.9986 - val_accuracy: 0.9998 - val_loss: 3.2900e-04 - val_precision: 0.9996 - val_recall: 1.0000
# Epoch 7/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9963 - loss: 0.0124 - precision: 0.9949 - recall: 0.9979 - val_accuracy: 1.0000 - val_loss: 2.4926e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 8/100
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9981 - loss: 0.0051 - precision: 0.9973 - recall: 0.9990 - val_accuracy: 0.9998 - val_loss: 2.7245e-04 - val_precision: 0.9996 - val_recall: 1.0000
# Epoch 9/100
# 264/385 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9973 - loss: 0.0087 - precision: 0.9968 - recall: 0.9980
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-f8eaf1eab6d5> in <cell line: 2>()
#       1 ## 모델 학습
# ----> 2 custom_model.fit(tr_idfd, validation_data=val_idfd,
#       3                  epochs=100, verbose=1,
#       4                  class_weight={0:1, 1:2}, ## 클래스 1에 대해 가중치를 더 주려는 의도
#       5                  callbacks=[es]
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     326                 for step, iterator in epoch_iterator:
#     327                     callbacks.on_train_batch_begin(step)
# --> 328                     logs = self.train_function(iterator)
#     329                     callbacks.on_train_batch_end(step, logs)
#     330                     if self.stop_training:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     173                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     174             ):
# --> 175                 opt_outputs = multi_step_on_iterator(iterator)
#     176                 if not opt_outputs.has_value():
#     177                     raise StopIteration
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1550     cancellation_context = cancellation.context()
#    1551     if cancellation_context is None:
# -> 1552       outputs = execute.execute(
#    1553           name.decode("utf-8"),
#    1554           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ### (2) 모델 추론

# %% [markdown]
# * **세부 요구사항**
#     - 학습된 모델의 성능을 확인해보세요.
#         - 임계값 조절, 클래스 가중치 부여 등으로 모델의 성능을 높여보세요.
#     - 예시 코드에서 사용한 라이브러리
#         - keras, sklearn

# %% [markdown]
# #### 1) 모델 추론

# %%
## image_dataset_from_directory로 만든 Test set로 예측값 생성
y_pred = custom_model.predict(te_idfd)
y_pred
# Out:
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 16s 75ms/step
# array([[1.0000000e+00],
#        [8.7908493e-06],
#        [9.9999988e-01],
#        ...,
#        [2.6604122e-08],
#        [1.9796500e-05],
#        [9.9999988e-01]], dtype=float32)

# %%
## 예측값에 대한 임계값을 0.5로 설정하여 0과 1로 구분
y_pred_fix = np.where(y_pred>=0.5, 1, 0)
y_pred_fix = y_pred_fix.flatten()
y_pred_fix
# Out:
# array([1, 0, 1, ..., 0, 0, 1])

# %%
len(y_pred_fix.nonzero()[0])
# Out:
# 2201

# %% [markdown]
# #### 2) 성능 확인

# %%
from sklearn.metrics import classification_report

# %%
## 성능 확인을 위하여 Test set의 Y만 떼와 array로 저장
temp = []

for te_x, te_y in te_idfd :
    temp.append(te_y.numpy())

y_true = np.concatenate(temp)

# %%
len(y_true.nonzero()[0])
# Out:
# 2200

# %%
print(classification_report(y_true, y_pred_fix, target_names=['other', 'my']) )
# Out:
#               precision    recall  f1-score   support
#
#        other       0.51      0.51      0.51      2200
#           my       0.51      0.51      0.51      2200
#
#     accuracy                           0.51      4400
#    macro avg       0.51      0.51      0.51      4400
# weighted avg       0.51      0.51      0.51      4400

# %% [markdown]
# ### (3) 모델 저장

# %% [markdown]
# * **세부 요구사항**
#     - **반드시 반드시 모델을 저장하고 로컬에 다운로드하세요.**
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 모델 저장

# %%
# 모델 저장 (.keras 확장자 사용)
custom_model.save('/content/custom_model.keras')
